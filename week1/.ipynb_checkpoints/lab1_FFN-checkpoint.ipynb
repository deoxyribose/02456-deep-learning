# %%
# %matplotlib inline
from __future__ import division, print_function
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import theano
import theano.tensor as T
import lasagne

def plot_decision_boundary(pred_func, X, y):
    #from https://github.com/dennybritz/nn-from-scratch/blob/master/nn-from-scratch.ipynb
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    yy = yy.astype('float32')
    xx = xx.astype('float32')
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])[:,0]
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

def onehot(t, num_classes):
    out = np.zeros((t.shape[0], num_classes))
    for row, col in enumerate(t):
        out[row, col] = 1
    return out

# %% [markdown]
# # Neural networks 101
# In this notebook you will implement a simple neural network in Lasagne utilizing the automatic differentiation engine of Theano. We assume that you are already familiar with backpropagation (if not please cf. [Andrej Karpathy](http://cs.stanford.edu/people/karpathy/) or [Michael Nielsen](http://neuralnetworksanddeeplearning.com/chap2.html).
# We'll not spend much time on how Theano works, but you can go through [this short tutorial](http://nbviewer.jupyter.org/github/craffel/theano-tutorial/blob/master/Theano%20Tutorial.ipynb) if you are interested).
#
# Additionally, for the ambitious people we have previously made an assignment where you will implement both the forward and backpropagation in a neural network by hand, https://github.com/DTU-deeplearning/day1-NN/blob/master/exercises_1.ipynb. By following this you will get a thorough understanding of the deep learning basics.
#
# In this exercise we'll start by defining a logistic regression model in Lasagne/Theano. Some details of Theano can be a bit confusing. For now you should pay most attention to the high-level network construction in Lasagne. We'll initially start with a simple 2-D and 2-class classification problem where the class decision boundary can be visualized. Initially we show that logistic regression can only separate classes linearly. Adding a non-linear hidden layer to the algorithm permits nonlinear class separation. If time permits we'll continue on to implement a fully connected neural network to classify the (in)famous MNIST dataset consisting of images of hand written digits.

# %% [markdown]
# # Problem
# We'll initally demonstrate that MLPs can classify non-linear problems whereas simple logistic regression cannot. For ease of visualization and computational speed we'll initially experiment on the simple 2D half-moon dataset.

# %%
# Generate a dataset and plot it
np.random.seed(0)
num_samples = 300

X, y = sklearn.datasets.make_moons(num_samples, noise=0.20)

X_tr = X[:100].astype('float32')
X_val = X[100:200].astype('float32')
X_te = X[200:].astype('float32')

y_tr = y[:100].astype('int32')
y_val = y[100:200].astype('int32')
y_te = y[200:].astype('int32')

plt.scatter(X_tr[:,0], X_tr[:,1], s=40, c=y_tr, cmap=plt.cm.BuGn)

print("Shape of the input matrix dim(%i x %i)." % X.shape)
print("Shape of the target matrix dim(%i)." % y.shape)

num_features = X_tr.shape[-1]
# Out:
# Shape of the input matrix dim(300 x 2).
# Shape of the target matrix dim(300).

# %% [markdown]
# # From Logistic Regression to "Deep Learning" in Lasagne
# The code implements logistic regression in Lasagne. In section __Assignments Half Moon__ you are asked to modify the code into a neural network.
#
# The building blocks of lasagne are the layers. To get started, the most frequently used layers are the DenseLayer and the InputLayer.
#
# The [InputLayer](http://lasagne.readthedocs.io/en/latest/modules/layers/input.html) is a "special" layer that lets you input data to the network. The InputLayer is initialized with a tuple specifying the shape of the input data. Note that it is common to provide ``None`` for the first dimension which allows you to vary the batch size at runtime.
#
# The [DenseLayer](http://lasagne.readthedocs.io/en/latest/modules/layers/dense.html) implements the computation:
#
# $$y = nonlinearity(xW + b)$$
#
# where $x$ is the layer input, $y$ is the layer output and $\{W, b\}$ are the layer parameters. The DenseLayer is initialized with a pointer to the previous layer, the desired number of units in the layer and the nonlinearity.
# x has shape ```[batchsize, num_features]```. From this we can infer the size of ```W``` as ```[num_features, num_units]``` and b as ```[num_units]```. y is then ```[batch_size, num_units]```.
#
#
# A layer in Lasagne does the following:
# 1. Given the shape of the input $x$ and the number of units in the layer, Lasagne infers the shapes of $W$ and $b$ and keep track of the layer parameters.
# 2. Computes $y = nonlinearity(xW + b)$

# %%
# ?lasagne.init.GlorotUniform

# %% [markdown]
# from lasagne.updates import sgd # stochastic gradient descent optimization algorithm.
# from lasagne.nonlinearities import leaky_rectify, softmax, tanh
# from lasagne.layers import InputLayer, DenseLayer
#
#
# #MODEL SPECIFICATION
# l_in = InputLayer(shape=(None, num_features))
# #INSERT HIDDEN LAYER HERE
# #l = DenseLayer(incoming=l,.....
# l_out = DenseLayer(incoming=l_in, num_units=2, nonlinearity=softmax, name='outputlayer')
# #We use two output units since we have two classes. The softmax function ensures that the the class probabilities sum to 1.

# %% [markdown]
# After we have built the network we can use the helper functions of lasagne to
#
# 1. Build the computational graph: __[lasagne.layers.get_output](http://lasagne.readthedocs.io/en/latest/modules/layers/helper.html#lasagne.layers.get_output)__ . The ``deterministic`` flag tells lasagne if we are in training mode or evaluation mode. When you build more complicated networks this is very important to remember! (Two important layers that behave differently in training mode and evaluation mode are the [DropoutLayer](http://lasagne.readthedocs.io/en/latest/modules/layers/noise.html#lasagne.layers.DropoutLayer) and the [BatchNormalizationLayer](http://lasagne.readthedocs.io/en/latest/modules/layers/normalization.html?highlight=batchnorm#lasagne.layers.BatchNormLayer)). Building the computational graph gives us the forward-pass of the network.
# 2. Collect the network parameters: __[lasagne.layers.get_all_params](http://lasagne.readthedocs.io/en/latest/modules/layers/helper.html#lasagne.layers.get_all_params)__ (Note the trainable flag which will only return parameters that are trainable. You'll get errors if your are using batchnorm and you forget this)
#
# Note that all the helper functions are called with the output layer or a list of output layers if you have multiple output layers.

# %%
sym_x = T.matrix('X') # a symbolic variable taking on the value of an input batch.
sym_t = T.ivector('target') # a symbolic variable taking on the value of the target batch.

# Get network output
train_out = lasagne.layers.get_output(l_out, {l_in: sym_x}, deterministic=False)
eval_out = lasagne.layers.get_output(l_out, {l_in: sym_x}, deterministic=True)

# Get list of all trainable parameters in the network.
all_params = lasagne.layers.get_all_params(l_out, trainable=True)

# print shapes of all the parameters in the network.
for p in all_params:
    print(p, p.get_value().shape)
# Out:
# outputlayer.W (2, 2)
# outputlayer.b (2,)

# %% [markdown]
# ``train_out`` will be a symbolic variable representing the network output. Using ``train_out`` we  can define the [crossentropy error](http://deeplearning.net/software/theano/library/tensor/nnet/nnet.html#tensor.nnet.categorical_crossentropy) used for training the network.
# We ```mean``` over all the samples in the mini-batch.

# %%
cost_train = T.nnet.categorical_crossentropy(train_out, sym_t).mean()
cost_eval = T.nnet.categorical_crossentropy(eval_out, sym_t).mean()

# %% [markdown]
# When we train a neural network we update the parameters in direction of the negative gradient w.r.t the cost.
# We can use ``T.grad`` to get the gradients for all parameters in the network w.r.t ``cost_train``.
# Imagine that ```cost_train``` is a function and we want to go downhill. We go downhill by changing the value of the parameters in direction of the negative gradient.
#
# Finally we can use __[lasagne.updates.sgd](http://lasagne.readthedocs.io/en/latest/modules/updates.html#lasagne.updates.sgd)__ to calculate the stochastic gradient descent (SGD) update rule for each parameter in the network. ``updates`` is a dictionary of the parameter update rules.
#
# Here's a small animation of [different optimizers doing](http://lasagne.readthedocs.io/en/latest/modules/updates.html) gradient descent: http://imgur.com/a/Hqolp . E.g why saddle points might be difficult.

# %%
# Let Theano do its magic and get all the gradients we need for training. Essentially T.grad does backprop i.e. get the 
# gradient of cost_train w.r.t. the parameters.
all_grads = T.grad(cost_train, all_params)

# Set the update function for parameters 
# you might want to experiment with more advanded update schemes like rmsprob, adadelta etc.
updates = lasagne.updates.sgd(all_grads, all_params, learning_rate=1.0)

# %% [markdown]
# The final step is to compile Theano functions for the network. For theano functions we need to specify which inputs the function should take. For our network that is ``sym_x``: the input data and ``sym_t``: the targets. Secondly we need to specify which outputs we want the network to return. In our case that is the cross-entropy cost and the network output.
#
# When we compile ``f_train`` we additionally give the update dictionary as input. This tells Theano to update the network parameters with the update rules everytime we call ``f_train``.

# %%
f_eval = theano.function(inputs=[sym_x, sym_t],
                         outputs=[cost_eval, eval_out])

f_train = theano.function(inputs=[sym_x, sym_t],
                          outputs=[cost_train, eval_out],
                          updates=updates)

#now you have three functions. 
# f_train(X,y) -> cost, y_pred which will update the parameters using backprop each time you call it, only use this on the training data!
# f_test(X,y) -> cost, y_pred which only calculates the forward pass

#This us just a helper function for plotting the decision boundaries between the two classes
f_pred = theano.function(inputs=[sym_x],
                         outputs=eval_out)

# %%
# Training loop
plot_decision_boundary(lambda x: f_pred(x), X_val,y_val)
plt.title("Untrained Classifier")
plt.colorbar()

num_epochs = 1000

train_cost, val_cost = [],[]
for e in range(num_epochs):
    out = f_train(X_tr,y_tr)
    #out = [cost, y_pred]
    train_cost += [out[0]]
    
    out = f_eval(X_val,y_val)
    val_cost += [out[0]]

    if e % 100 == 0:
        print("Epoch %i, Train Cost: %0.3f\tVal Cost: %0.3f"%(e, train_cost[-1],val_cost[-1]))
    
    
out = f_eval(X_te,y_te)
test_cost = out[0]
print("\nTest Cost: %0.3f"%(test_cost))

plot_decision_boundary(lambda x: f_pred(x), X_te, y_te)
plt.title("Trained Classifier")
plt.colorbar()

epoch = np.arange(len(train_cost))
plt.figure()
plt.plot(epoch,train_cost,'r',epoch,val_cost,'b')
plt.legend(['Train Loss','Val Loss'])
plt.xlabel('Updates'), plt.ylabel('Loss')
# Out:
# Epoch 0, Train Cost: 1.066	Val Cost: 0.784
# Epoch 100, Train Cost: 0.303	Val Cost: 0.332
# Epoch 200, Train Cost: 0.302	Val Cost: 0.333
# Epoch 300, Train Cost: 0.302	Val Cost: 0.334
# Epoch 400, Train Cost: 0.302	Val Cost: 0.334
# Epoch 500, Train Cost: 0.302	Val Cost: 0.334
# Epoch 600, Train Cost: 0.302	Val Cost: 0.334
# Epoch 700, Train Cost: 0.302	Val Cost: 0.334
# Epoch 800, Train Cost: 0.302	Val Cost: 0.334
# Epoch 900, Train Cost: 0.302	Val Cost: 0.334
#
# Test Cost: 0.270
# (<matplotlib.text.Text at 0x7f25cddc6588>,
#  <matplotlib.text.Text at 0x7f25cddce780>)

# %% [markdown]
# # Assignments Half Moon
#
#  1) A linear logistic classifier is only able to create a linear decision boundary. Change the Logistic classifier into a (non-linear) neural network by inserting a dense hidden layer between the input and output layers of the model

# %% [markdown]
# #### I add a 2-unit hidden layer with the tanh nonlinearity
#
# #### Everything in the next cell is copy & paste from above

# %%
def train_network(n_epochs = 1000, num_hidden_units = 2, verbose = True, draw = False):
    #MODEL SPECIFICATION
    l_in = InputLayer(shape=(None, num_features))
    #INSERT HIDDEN LAYER HERE
    #l = DenseLayer(incoming=l,.....
    l_hidden = DenseLayer(incoming=l_in, num_units=num_hidden_units, nonlinearity=tanh, name='hidden')
    l_out = DenseLayer(incoming=l_hidden, num_units=2, nonlinearity=softmax, name='outputlayer') 
    #We use two output units since we have two classes. The softmax function ensures that the the class probabilities sum to 1.
    # Get network output
    train_out = lasagne.layers.get_output(l_out, {l_in: sym_x}, deterministic=False)
    eval_out = lasagne.layers.get_output(l_out, {l_in: sym_x}, deterministic=True)

    # Get list of all trainable parameters in the network.
    all_params = lasagne.layers.get_all_params(l_out, trainable=True)

    # print shapes of all the parameters in the network.
    for p in all_params:
        print(p, p.get_value().shape)

    cost_train = T.nnet.categorical_crossentropy(train_out, sym_t).mean()
    cost_eval = T.nnet.categorical_crossentropy(eval_out, sym_t).mean()

    # Let Theano do its magic and get all the gradients we need for training. Essentially T.grad does backprop i.e. get the 
    # gradient of cost_train w.r.t. the parameters.
    all_grads = T.grad(cost_train, all_params)

    # Set the update function for parameters 
    # you might want to experiment with more advanded update schemes like rmsprob, adadelta etc.
    updates = lasagne.updates.sgd(all_grads, all_params, learning_rate=1.0)

    f_eval = theano.function(inputs=[sym_x, sym_t],
                             outputs=[cost_eval, eval_out])

    f_train = theano.function(inputs=[sym_x, sym_t],
                              outputs=[cost_train, eval_out],
                              updates=updates)

    #now you have three functions. 
    # f_train(X,y) -> cost, y_pred which will update the parameters using backprop each time you call it, only use this on the training data!
    # f_test(X,y) -> cost, y_pred which only calculates the forward pass

    #This us just a helper function for plotting the decision boundaries between the two classes
    f_pred = theano.function(inputs=[sym_x],
                             outputs=eval_out)

    if draw:
        # Training loop
        plot_decision_boundary(lambda x: f_pred(x), X_val,y_val)
        plt.title("Untrained Classifier")
        plt.colorbar()

    train_cost, val_cost = [],[]
    for e in range(num_epochs):
        out = f_train(X_tr,y_tr)
        #out = [cost, y_pred]
        train_cost += [out[0]]

        out = f_eval(X_val,y_val)
        val_cost += [out[0]]

        if verbose:
            if e % 100 == 0:
                print("Epoch %i, Train Cost: %0.3f\tVal Cost: %0.3f"%(e, train_cost[-1],val_cost[-1]))


    out = f_eval(X_te,y_te)
    test_cost = out[0]
    if verbose:
        print("\nTest Cost: %0.3f"%(test_cost))
    
    if draw:
        plot_decision_boundary(lambda x: f_pred(x), X_te, y_te)
        plt.title("Trained Classifier")
        plt.colorbar()

        epoch = np.arange(len(train_cost))
        plt.figure()
        plt.plot(epoch,train_cost,'r',epoch,val_cost,'b')
        plt.legend(['Train Loss','Val Loss'])
        plt.xlabel('Updates'), plt.ylabel('Loss')
    return (train_cost[-1],val_cost[-1],test_cost)

# %% [markdown]
# #### With 2 hidden units in 1 layer, the test error varies a lot between different initializations

# %%
n_runs = 10
test_errors = [train_network() for i in range(n_runs)]
# Out:
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.081	Val Cost: 0.618
# Epoch 100, Train Cost: 0.310	Val Cost: 0.337
# Epoch 200, Train Cost: 0.305	Val Cost: 0.334
# Epoch 300, Train Cost: 0.297	Val Cost: 0.331
# Epoch 400, Train Cost: 0.287	Val Cost: 0.329
# Epoch 500, Train Cost: 0.279	Val Cost: 0.329
# Epoch 600, Train Cost: 0.274	Val Cost: 0.329
# Epoch 700, Train Cost: 0.270	Val Cost: 0.330
# Epoch 800, Train Cost: 0.268	Val Cost: 0.331
# Epoch 900, Train Cost: 0.265	Val Cost: 0.332
#
# Test Cost: 0.304
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.562	Val Cost: 0.447
# Epoch 100, Train Cost: 0.312	Val Cost: 0.337
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.307	Val Cost: 0.336
# Epoch 400, Train Cost: 0.302	Val Cost: 0.333
# Epoch 500, Train Cost: 0.295	Val Cost: 0.332
# Epoch 600, Train Cost: 0.286	Val Cost: 0.331
# Epoch 700, Train Cost: 0.279	Val Cost: 0.329
# Epoch 800, Train Cost: 0.273	Val Cost: 0.329
# Epoch 900, Train Cost: 0.270	Val Cost: 0.329
#
# Test Cost: 0.293
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.617	Val Cost: 0.545
# Epoch 100, Train Cost: 0.241	Val Cost: 0.272
# Epoch 200, Train Cost: 0.147	Val Cost: 0.207
# Epoch 300, Train Cost: 0.140	Val Cost: 0.251
# Epoch 400, Train Cost: 0.125	Val Cost: 0.259
# Epoch 500, Train Cost: 0.114	Val Cost: 0.269
# Epoch 600, Train Cost: 0.106	Val Cost: 0.281
# Epoch 700, Train Cost: 0.100	Val Cost: 0.292
# Epoch 800, Train Cost: 0.095	Val Cost: 0.305
# Epoch 900, Train Cost: 0.091	Val Cost: 0.319
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.778	Val Cost: 0.686
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.334
# Epoch 400, Train Cost: 0.301	Val Cost: 0.333
# Epoch 500, Train Cost: 0.293	Val Cost: 0.332
# Epoch 600, Train Cost: 0.284	Val Cost: 0.330
# Epoch 700, Train Cost: 0.277	Val Cost: 0.329
# Epoch 800, Train Cost: 0.273	Val Cost: 0.329
# Epoch 900, Train Cost: 0.269	Val Cost: 0.330
#
# Test Cost: 0.294
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.619	Val Cost: 0.516
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.314	Val Cost: 0.348
# Epoch 400, Train Cost: 0.306	Val Cost: 0.334
# Epoch 500, Train Cost: 0.302	Val Cost: 0.333
# Epoch 600, Train Cost: 0.294	Val Cost: 0.332
# Epoch 700, Train Cost: 0.285	Val Cost: 0.331
# Epoch 800, Train Cost: 0.278	Val Cost: 0.329
# Epoch 900, Train Cost: 0.273	Val Cost: 0.328
#
# Test Cost: 0.286
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.088	Val Cost: 0.702
# Epoch 100, Train Cost: 0.293	Val Cost: 0.323
# Epoch 200, Train Cost: 0.301	Val Cost: 0.320
# Epoch 300, Train Cost: 0.295	Val Cost: 0.316
# Epoch 400, Train Cost: 0.292	Val Cost: 0.314
# Epoch 500, Train Cost: 0.290	Val Cost: 0.312
# Epoch 600, Train Cost: 0.288	Val Cost: 0.312
# Epoch 700, Train Cost: 0.287	Val Cost: 0.311
# Epoch 800, Train Cost: 0.286	Val Cost: 0.311
# Epoch 900, Train Cost: 0.285	Val Cost: 0.311
#
# Test Cost: 0.258
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.568	Val Cost: 0.511
# Epoch 100, Train Cost: 0.301	Val Cost: 0.329
# Epoch 200, Train Cost: 0.306	Val Cost: 0.353
# Epoch 300, Train Cost: 0.300	Val Cost: 0.345
# Epoch 400, Train Cost: 0.296	Val Cost: 0.340
# Epoch 500, Train Cost: 0.293	Val Cost: 0.337
# Epoch 600, Train Cost: 0.291	Val Cost: 0.334
# Epoch 700, Train Cost: 0.290	Val Cost: 0.332
# Epoch 800, Train Cost: 0.288	Val Cost: 0.331
# Epoch 900, Train Cost: 0.287	Val Cost: 0.330
#
# Test Cost: 0.235
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.464	Val Cost: 0.421
# Epoch 100, Train Cost: 0.309	Val Cost: 0.335
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.304	Val Cost: 0.333
# Epoch 400, Train Cost: 0.297	Val Cost: 0.333
# Epoch 500, Train Cost: 0.288	Val Cost: 0.332
# Epoch 600, Train Cost: 0.281	Val Cost: 0.330
# Epoch 700, Train Cost: 0.275	Val Cost: 0.329
# Epoch 800, Train Cost: 0.271	Val Cost: 0.329
# Epoch 900, Train Cost: 0.268	Val Cost: 0.329
#
# Test Cost: 0.297
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.549	Val Cost: 0.514
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.309	Val Cost: 0.332
# Epoch 400, Train Cost: 0.304	Val Cost: 0.333
# Epoch 500, Train Cost: 0.297	Val Cost: 0.333
# Epoch 600, Train Cost: 0.289	Val Cost: 0.332
# Epoch 700, Train Cost: 0.281	Val Cost: 0.330
# Epoch 800, Train Cost: 0.275	Val Cost: 0.329
# Epoch 900, Train Cost: 0.271	Val Cost: 0.328
#
# Test Cost: 0.290
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.887	Val Cost: 0.737
# Epoch 100, Train Cost: 0.306	Val Cost: 0.335
# Epoch 200, Train Cost: 0.294	Val Cost: 0.330
# Epoch 300, Train Cost: 0.284	Val Cost: 0.327
# Epoch 400, Train Cost: 0.277	Val Cost: 0.326
# Epoch 500, Train Cost: 0.273	Val Cost: 0.325
# Epoch 600, Train Cost: 0.269	Val Cost: 0.326
# Epoch 700, Train Cost: 0.267	Val Cost: 0.327
# Epoch 800, Train Cost: 0.265	Val Cost: 0.328
# Epoch 900, Train Cost: 0.263	Val Cost: 0.329
#
# Test Cost: 0.312
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.475	Val Cost: 0.444
# Epoch 100, Train Cost: 0.259	Val Cost: 0.286
# Epoch 200, Train Cost: 0.158	Val Cost: 0.213
# Epoch 300, Train Cost: 0.143	Val Cost: 0.249
# Epoch 400, Train Cost: 0.127	Val Cost: 0.257
# Epoch 500, Train Cost: 0.115	Val Cost: 0.268
# Epoch 600, Train Cost: 0.107	Val Cost: 0.279
# Epoch 700, Train Cost: 0.101	Val Cost: 0.290
# Epoch 800, Train Cost: 0.096	Val Cost: 0.303
# Epoch 900, Train Cost: 0.092	Val Cost: 0.316
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.824	Val Cost: 0.723
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.304	Val Cost: 0.333
# Epoch 400, Train Cost: 0.297	Val Cost: 0.331
# Epoch 500, Train Cost: 0.288	Val Cost: 0.329
# Epoch 600, Train Cost: 0.280	Val Cost: 0.329
# Epoch 700, Train Cost: 0.274	Val Cost: 0.330
# Epoch 800, Train Cost: 0.271	Val Cost: 0.332
# Epoch 900, Train Cost: 0.268	Val Cost: 0.333
#
# Test Cost: 0.298
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.087	Val Cost: 0.709
# Epoch 100, Train Cost: 0.301	Val Cost: 0.330
# Epoch 200, Train Cost: 0.304	Val Cost: 0.351
# Epoch 300, Train Cost: 0.298	Val Cost: 0.343
# Epoch 400, Train Cost: 0.294	Val Cost: 0.339
# Epoch 500, Train Cost: 0.291	Val Cost: 0.336
# Epoch 600, Train Cost: 0.289	Val Cost: 0.334
# Epoch 700, Train Cost: 0.288	Val Cost: 0.333
# Epoch 800, Train Cost: 0.286	Val Cost: 0.332
# Epoch 900, Train Cost: 0.285	Val Cost: 0.331
#
# Test Cost: 0.240
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.618	Val Cost: 0.469
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.334
# Epoch 400, Train Cost: 0.300	Val Cost: 0.333
# Epoch 500, Train Cost: 0.291	Val Cost: 0.331
# Epoch 600, Train Cost: 0.283	Val Cost: 0.330
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.329
# Epoch 900, Train Cost: 0.269	Val Cost: 0.330
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.017	Val Cost: 0.775
# Epoch 100, Train Cost: 0.308	Val Cost: 0.334
# Epoch 200, Train Cost: 0.314	Val Cost: 0.328
# Epoch 300, Train Cost: 0.305	Val Cost: 0.320
# Epoch 400, Train Cost: 0.300	Val Cost: 0.316
# Epoch 500, Train Cost: 0.297	Val Cost: 0.312
# Epoch 600, Train Cost: 0.294	Val Cost: 0.310
# Epoch 700, Train Cost: 0.292	Val Cost: 0.309
# Epoch 800, Train Cost: 0.291	Val Cost: 0.308
# Epoch 900, Train Cost: 0.290	Val Cost: 0.307
#
# Test Cost: 0.258
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.575	Val Cost: 0.524
# Epoch 100, Train Cost: 0.308	Val Cost: 0.336
# Epoch 200, Train Cost: 0.301	Val Cost: 0.337
# Epoch 300, Train Cost: 0.294	Val Cost: 0.338
# Epoch 400, Train Cost: 0.287	Val Cost: 0.338
# Epoch 500, Train Cost: 0.281	Val Cost: 0.337
# Epoch 600, Train Cost: 0.276	Val Cost: 0.334
# Epoch 700, Train Cost: 0.271	Val Cost: 0.330
# Epoch 800, Train Cost: 0.268	Val Cost: 0.329
# Epoch 900, Train Cost: 0.266	Val Cost: 0.329
#
# Test Cost: 0.304
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.543	Val Cost: 0.486
# Epoch 100, Train Cost: 0.224	Val Cost: 0.257
# Epoch 200, Train Cost: 0.156	Val Cost: 0.211
# Epoch 300, Train Cost: 0.149	Val Cost: 0.216
# Epoch 400, Train Cost: 0.135	Val Cost: 0.222
# Epoch 500, Train Cost: 0.126	Val Cost: 0.232
# Epoch 600, Train Cost: 0.119	Val Cost: 0.243
# Epoch 700, Train Cost: 0.114	Val Cost: 0.255
# Epoch 800, Train Cost: 0.109	Val Cost: 0.267
# Epoch 900, Train Cost: 0.105	Val Cost: 0.281
#
# Test Cost: 0.124
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.095	Val Cost: 0.700
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.333
# Epoch 400, Train Cost: 0.301	Val Cost: 0.332
# Epoch 500, Train Cost: 0.291	Val Cost: 0.329
# Epoch 600, Train Cost: 0.282	Val Cost: 0.328
# Epoch 700, Train Cost: 0.276	Val Cost: 0.330
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.333
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.763	Val Cost: 0.661
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.305	Val Cost: 0.334
# Epoch 300, Train Cost: 0.299	Val Cost: 0.334
# Epoch 400, Train Cost: 0.291	Val Cost: 0.334
# Epoch 500, Train Cost: 0.283	Val Cost: 0.332
# Epoch 600, Train Cost: 0.277	Val Cost: 0.330
# Epoch 700, Train Cost: 0.272	Val Cost: 0.328
# Epoch 800, Train Cost: 0.269	Val Cost: 0.328
# Epoch 900, Train Cost: 0.266	Val Cost: 0.329
#
# Test Cost: 0.301
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.151	Val Cost: 0.655
# Epoch 100, Train Cost: 0.235	Val Cost: 0.265
# Epoch 200, Train Cost: 0.178	Val Cost: 0.218
# Epoch 300, Train Cost: 0.151	Val Cost: 0.215
# Epoch 400, Train Cost: 0.137	Val Cost: 0.221
# Epoch 500, Train Cost: 0.127	Val Cost: 0.231
# Epoch 600, Train Cost: 0.120	Val Cost: 0.242
# Epoch 700, Train Cost: 0.114	Val Cost: 0.253
# Epoch 800, Train Cost: 0.109	Val Cost: 0.266
# Epoch 900, Train Cost: 0.106	Val Cost: 0.279
#
# Test Cost: 0.125
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.725	Val Cost: 0.645
# Epoch 100, Train Cost: 0.314	Val Cost: 0.338
# Epoch 200, Train Cost: 0.330	Val Cost: 0.339
# Epoch 300, Train Cost: 0.323	Val Cost: 0.333
# Epoch 400, Train Cost: 0.228	Val Cost: 0.251
# Epoch 500, Train Cost: 0.173	Val Cost: 0.216
# Epoch 600, Train Cost: 0.149	Val Cost: 0.215
# Epoch 700, Train Cost: 0.135	Val Cost: 0.222
# Epoch 800, Train Cost: 0.126	Val Cost: 0.232
# Epoch 900, Train Cost: 0.119	Val Cost: 0.243
#
# Test Cost: 0.137
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.800	Val Cost: 0.584
# Epoch 100, Train Cost: 0.314	Val Cost: 0.338
# Epoch 200, Train Cost: 0.323	Val Cost: 0.363
# Epoch 300, Train Cost: 0.319	Val Cost: 0.355
# Epoch 400, Train Cost: 0.316	Val Cost: 0.350
# Epoch 500, Train Cost: 0.309	Val Cost: 0.338
# Epoch 600, Train Cost: 0.303	Val Cost: 0.332
# Epoch 700, Train Cost: 0.297	Val Cost: 0.333
# Epoch 800, Train Cost: 0.289	Val Cost: 0.333
# Epoch 900, Train Cost: 0.282	Val Cost: 0.331
#
# Test Cost: 0.275
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.548	Val Cost: 0.494
# Epoch 100, Train Cost: 0.314	Val Cost: 0.338
# Epoch 200, Train Cost: 0.330	Val Cost: 0.338
# Epoch 300, Train Cost: 0.314	Val Cost: 0.326
# Epoch 400, Train Cost: 0.306	Val Cost: 0.319
# Epoch 500, Train Cost: 0.301	Val Cost: 0.314
# Epoch 600, Train Cost: 0.298	Val Cost: 0.311
# Epoch 700, Train Cost: 0.296	Val Cost: 0.308
# Epoch 800, Train Cost: 0.294	Val Cost: 0.307
# Epoch 900, Train Cost: 0.293	Val Cost: 0.306
#
# Test Cost: 0.262
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.651	Val Cost: 0.418
# Epoch 100, Train Cost: 0.307	Val Cost: 0.335
# Epoch 200, Train Cost: 0.300	Val Cost: 0.334
# Epoch 300, Train Cost: 0.291	Val Cost: 0.333
# Epoch 400, Train Cost: 0.283	Val Cost: 0.331
# Epoch 500, Train Cost: 0.276	Val Cost: 0.329
# Epoch 600, Train Cost: 0.272	Val Cost: 0.328
# Epoch 700, Train Cost: 0.269	Val Cost: 0.328
# Epoch 800, Train Cost: 0.266	Val Cost: 0.329
# Epoch 900, Train Cost: 0.264	Val Cost: 0.330
#
# Test Cost: 0.308
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.801	Val Cost: 0.653
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.335
# Epoch 300, Train Cost: 0.305	Val Cost: 0.334
# Epoch 400, Train Cost: 0.298	Val Cost: 0.332
# Epoch 500, Train Cost: 0.289	Val Cost: 0.330
# Epoch 600, Train Cost: 0.281	Val Cost: 0.330
# Epoch 700, Train Cost: 0.275	Val Cost: 0.330
# Epoch 800, Train Cost: 0.271	Val Cost: 0.330
# Epoch 900, Train Cost: 0.268	Val Cost: 0.331
#
# Test Cost: 0.297
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.721	Val Cost: 0.681
# Epoch 100, Train Cost: 0.296	Val Cost: 0.324
# Epoch 200, Train Cost: 0.303	Val Cost: 0.350
# Epoch 300, Train Cost: 0.298	Val Cost: 0.342
# Epoch 400, Train Cost: 0.295	Val Cost: 0.338
# Epoch 500, Train Cost: 0.293	Val Cost: 0.335
# Epoch 600, Train Cost: 0.291	Val Cost: 0.333
# Epoch 700, Train Cost: 0.290	Val Cost: 0.331
# Epoch 800, Train Cost: 0.289	Val Cost: 0.330
# Epoch 900, Train Cost: 0.289	Val Cost: 0.330
#
# Test Cost: 0.232
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.636	Val Cost: 0.570
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.334
# Epoch 300, Train Cost: 0.305	Val Cost: 0.333
# Epoch 400, Train Cost: 0.299	Val Cost: 0.331
# Epoch 500, Train Cost: 0.289	Val Cost: 0.329
# Epoch 600, Train Cost: 0.281	Val Cost: 0.329
# Epoch 700, Train Cost: 0.275	Val Cost: 0.330
# Epoch 800, Train Cost: 0.271	Val Cost: 0.331
# Epoch 900, Train Cost: 0.268	Val Cost: 0.332
#
# Test Cost: 0.297
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.771	Val Cost: 0.641
# Epoch 100, Train Cost: 0.223	Val Cost: 0.256
# Epoch 200, Train Cost: 0.149	Val Cost: 0.206
# Epoch 300, Train Cost: 0.149	Val Cost: 0.216
# Epoch 400, Train Cost: 0.135	Val Cost: 0.223
# Epoch 500, Train Cost: 0.126	Val Cost: 0.232
# Epoch 600, Train Cost: 0.119	Val Cost: 0.243
# Epoch 700, Train Cost: 0.113	Val Cost: 0.255
# Epoch 800, Train Cost: 0.109	Val Cost: 0.268
# Epoch 900, Train Cost: 0.105	Val Cost: 0.281
#
# Test Cost: 0.124
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.555	Val Cost: 0.457
# Epoch 100, Train Cost: 0.309	Val Cost: 0.336
# Epoch 200, Train Cost: 0.303	Val Cost: 0.334
# Epoch 300, Train Cost: 0.294	Val Cost: 0.332
# Epoch 400, Train Cost: 0.285	Val Cost: 0.330
# Epoch 500, Train Cost: 0.278	Val Cost: 0.328
# Epoch 600, Train Cost: 0.273	Val Cost: 0.328
# Epoch 700, Train Cost: 0.270	Val Cost: 0.328
# Epoch 800, Train Cost: 0.267	Val Cost: 0.329
# Epoch 900, Train Cost: 0.265	Val Cost: 0.330
#
# Test Cost: 0.306
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.991	Val Cost: 0.691
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.307	Val Cost: 0.332
# Epoch 400, Train Cost: 0.301	Val Cost: 0.332
# Epoch 500, Train Cost: 0.291	Val Cost: 0.329
# Epoch 600, Train Cost: 0.283	Val Cost: 0.328
# Epoch 700, Train Cost: 0.276	Val Cost: 0.330
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.333
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.484	Val Cost: 0.414
# Epoch 100, Train Cost: 0.309	Val Cost: 0.335
# Epoch 200, Train Cost: 0.300	Val Cost: 0.333
# Epoch 300, Train Cost: 0.290	Val Cost: 0.330
# Epoch 400, Train Cost: 0.281	Val Cost: 0.328
# Epoch 500, Train Cost: 0.275	Val Cost: 0.327
# Epoch 600, Train Cost: 0.271	Val Cost: 0.327
# Epoch 700, Train Cost: 0.268	Val Cost: 0.328
# Epoch 800, Train Cost: 0.266	Val Cost: 0.328
# Epoch 900, Train Cost: 0.264	Val Cost: 0.329
#
# Test Cost: 0.309
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.563	Val Cost: 0.540
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.304	Val Cost: 0.333
# Epoch 400, Train Cost: 0.297	Val Cost: 0.331
# Epoch 500, Train Cost: 0.287	Val Cost: 0.330
# Epoch 600, Train Cost: 0.279	Val Cost: 0.329
# Epoch 700, Train Cost: 0.274	Val Cost: 0.330
# Epoch 800, Train Cost: 0.270	Val Cost: 0.330
# Epoch 900, Train Cost: 0.268	Val Cost: 0.331
#
# Test Cost: 0.298
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.775	Val Cost: 0.596
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.307	Val Cost: 0.336
# Epoch 400, Train Cost: 0.303	Val Cost: 0.333
# Epoch 500, Train Cost: 0.295	Val Cost: 0.332
# Epoch 600, Train Cost: 0.286	Val Cost: 0.331
# Epoch 700, Train Cost: 0.279	Val Cost: 0.329
# Epoch 800, Train Cost: 0.274	Val Cost: 0.328
# Epoch 900, Train Cost: 0.270	Val Cost: 0.329
#
# Test Cost: 0.292
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.702	Val Cost: 0.534
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.308	Val Cost: 0.338
# Epoch 400, Train Cost: 0.303	Val Cost: 0.333
# Epoch 500, Train Cost: 0.295	Val Cost: 0.330
# Epoch 600, Train Cost: 0.286	Val Cost: 0.329
# Epoch 700, Train Cost: 0.278	Val Cost: 0.329
# Epoch 800, Train Cost: 0.273	Val Cost: 0.330
# Epoch 900, Train Cost: 0.270	Val Cost: 0.331
#
# Test Cost: 0.292
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.639	Val Cost: 0.514
# Epoch 100, Train Cost: 0.234	Val Cost: 0.262
# Epoch 200, Train Cost: 0.223	Val Cost: 0.366
# Epoch 300, Train Cost: 0.146	Val Cost: 0.241
# Epoch 400, Train Cost: 0.128	Val Cost: 0.252
# Epoch 500, Train Cost: 0.116	Val Cost: 0.264
# Epoch 600, Train Cost: 0.107	Val Cost: 0.276
# Epoch 700, Train Cost: 0.101	Val Cost: 0.287
# Epoch 800, Train Cost: 0.096	Val Cost: 0.299
# Epoch 900, Train Cost: 0.092	Val Cost: 0.313
#
# Test Cost: 0.092
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.560	Val Cost: 0.494
# Epoch 100, Train Cost: 0.273	Val Cost: 0.300
# Epoch 200, Train Cost: 0.156	Val Cost: 0.232
# Epoch 300, Train Cost: 0.144	Val Cost: 0.250
# Epoch 400, Train Cost: 0.127	Val Cost: 0.258
# Epoch 500, Train Cost: 0.116	Val Cost: 0.268
# Epoch 600, Train Cost: 0.108	Val Cost: 0.279
# Epoch 700, Train Cost: 0.101	Val Cost: 0.290
# Epoch 800, Train Cost: 0.096	Val Cost: 0.303
# Epoch 900, Train Cost: 0.092	Val Cost: 0.316
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.759	Val Cost: 0.691
# Epoch 100, Train Cost: 0.244	Val Cost: 0.273
# Epoch 200, Train Cost: 0.242	Val Cost: 0.233
# Epoch 300, Train Cost: 0.152	Val Cost: 0.215
# Epoch 400, Train Cost: 0.137	Val Cost: 0.221
# Epoch 500, Train Cost: 0.127	Val Cost: 0.231
# Epoch 600, Train Cost: 0.120	Val Cost: 0.242
# Epoch 700, Train Cost: 0.114	Val Cost: 0.253
# Epoch 800, Train Cost: 0.110	Val Cost: 0.266
# Epoch 900, Train Cost: 0.106	Val Cost: 0.279
#
# Test Cost: 0.125
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.624	Val Cost: 0.558
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.301	Val Cost: 0.332
# Epoch 400, Train Cost: 0.291	Val Cost: 0.329
# Epoch 500, Train Cost: 0.282	Val Cost: 0.328
# Epoch 600, Train Cost: 0.276	Val Cost: 0.329
# Epoch 700, Train Cost: 0.272	Val Cost: 0.331
# Epoch 800, Train Cost: 0.269	Val Cost: 0.332
# Epoch 900, Train Cost: 0.266	Val Cost: 0.333
#
# Test Cost: 0.302
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.422	Val Cost: 0.430
# Epoch 100, Train Cost: 0.312	Val Cost: 0.337
# Epoch 200, Train Cost: 0.306	Val Cost: 0.334
# Epoch 300, Train Cost: 0.300	Val Cost: 0.331
# Epoch 400, Train Cost: 0.291	Val Cost: 0.329
# Epoch 500, Train Cost: 0.282	Val Cost: 0.328
# Epoch 600, Train Cost: 0.276	Val Cost: 0.329
# Epoch 700, Train Cost: 0.272	Val Cost: 0.331
# Epoch 800, Train Cost: 0.269	Val Cost: 0.332
# Epoch 900, Train Cost: 0.266	Val Cost: 0.333
#
# Test Cost: 0.302
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.746	Val Cost: 0.700
# Epoch 100, Train Cost: 0.309	Val Cost: 0.335
# Epoch 200, Train Cost: 0.304	Val Cost: 0.335
# Epoch 300, Train Cost: 0.298	Val Cost: 0.336
# Epoch 400, Train Cost: 0.291	Val Cost: 0.337
# Epoch 500, Train Cost: 0.284	Val Cost: 0.337
# Epoch 600, Train Cost: 0.278	Val Cost: 0.335
# Epoch 700, Train Cost: 0.273	Val Cost: 0.331
# Epoch 800, Train Cost: 0.269	Val Cost: 0.329
# Epoch 900, Train Cost: 0.267	Val Cost: 0.329
#
# Test Cost: 0.301
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.681	Val Cost: 0.675
# Epoch 100, Train Cost: 0.307	Val Cost: 0.335
# Epoch 200, Train Cost: 0.297	Val Cost: 0.329
# Epoch 300, Train Cost: 0.287	Val Cost: 0.326
# Epoch 400, Train Cost: 0.279	Val Cost: 0.326
# Epoch 500, Train Cost: 0.274	Val Cost: 0.327
# Epoch 600, Train Cost: 0.270	Val Cost: 0.329
# Epoch 700, Train Cost: 0.267	Val Cost: 0.330
# Epoch 800, Train Cost: 0.265	Val Cost: 0.332
# Epoch 900, Train Cost: 0.264	Val Cost: 0.333
#
# Test Cost: 0.311
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.822	Val Cost: 0.645
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.333
# Epoch 400, Train Cost: 0.301	Val Cost: 0.332
# Epoch 500, Train Cost: 0.292	Val Cost: 0.329
# Epoch 600, Train Cost: 0.283	Val Cost: 0.328
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.705	Val Cost: 0.688
# Epoch 100, Train Cost: 0.314	Val Cost: 0.337
# Epoch 200, Train Cost: 0.281	Val Cost: 0.296
# Epoch 300, Train Cost: 0.191	Val Cost: 0.221
# Epoch 400, Train Cost: 0.159	Val Cost: 0.212
# Epoch 500, Train Cost: 0.141	Val Cost: 0.218
# Epoch 600, Train Cost: 0.130	Val Cost: 0.227
# Epoch 700, Train Cost: 0.122	Val Cost: 0.238
# Epoch 800, Train Cost: 0.116	Val Cost: 0.249
# Epoch 900, Train Cost: 0.111	Val Cost: 0.261
#
# Test Cost: 0.130
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.480	Val Cost: 0.429
# Epoch 100, Train Cost: 0.270	Val Cost: 0.295
# Epoch 200, Train Cost: 0.190	Val Cost: 0.223
# Epoch 300, Train Cost: 0.156	Val Cost: 0.214
# Epoch 400, Train Cost: 0.140	Val Cost: 0.219
# Epoch 500, Train Cost: 0.129	Val Cost: 0.228
# Epoch 600, Train Cost: 0.121	Val Cost: 0.239
# Epoch 700, Train Cost: 0.115	Val Cost: 0.251
# Epoch 800, Train Cost: 0.110	Val Cost: 0.263
# Epoch 900, Train Cost: 0.106	Val Cost: 0.276
#
# Test Cost: 0.125
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.980	Val Cost: 0.696
# Epoch 100, Train Cost: 0.247	Val Cost: 0.277
# Epoch 200, Train Cost: 0.153	Val Cost: 0.212
# Epoch 300, Train Cost: 0.141	Val Cost: 0.249
# Epoch 400, Train Cost: 0.125	Val Cost: 0.259
# Epoch 500, Train Cost: 0.115	Val Cost: 0.269
# Epoch 600, Train Cost: 0.107	Val Cost: 0.280
# Epoch 700, Train Cost: 0.100	Val Cost: 0.292
# Epoch 800, Train Cost: 0.095	Val Cost: 0.304
# Epoch 900, Train Cost: 0.091	Val Cost: 0.318
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.868	Val Cost: 0.724
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.313	Val Cost: 0.347
# Epoch 400, Train Cost: 0.305	Val Cost: 0.334
# Epoch 500, Train Cost: 0.299	Val Cost: 0.331
# Epoch 600, Train Cost: 0.289	Val Cost: 0.328
# Epoch 700, Train Cost: 0.281	Val Cost: 0.328
# Epoch 800, Train Cost: 0.275	Val Cost: 0.329
# Epoch 900, Train Cost: 0.271	Val Cost: 0.331
#
# Test Cost: 0.290
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.829	Val Cost: 0.710
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.305	Val Cost: 0.334
# Epoch 300, Train Cost: 0.297	Val Cost: 0.332
# Epoch 400, Train Cost: 0.288	Val Cost: 0.331
# Epoch 500, Train Cost: 0.280	Val Cost: 0.329
# Epoch 600, Train Cost: 0.274	Val Cost: 0.328
# Epoch 700, Train Cost: 0.270	Val Cost: 0.328
# Epoch 800, Train Cost: 0.268	Val Cost: 0.329
# Epoch 900, Train Cost: 0.266	Val Cost: 0.330
#
# Test Cost: 0.304
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.595	Val Cost: 0.543
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.315	Val Cost: 0.351
# Epoch 400, Train Cost: 0.312	Val Cost: 0.346
# Epoch 500, Train Cost: 0.305	Val Cost: 0.333
# Epoch 600, Train Cost: 0.299	Val Cost: 0.331
# Epoch 700, Train Cost: 0.289	Val Cost: 0.328
# Epoch 800, Train Cost: 0.281	Val Cost: 0.328
# Epoch 900, Train Cost: 0.275	Val Cost: 0.329
#
# Test Cost: 0.283
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.788	Val Cost: 0.610
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.304	Val Cost: 0.334
# Epoch 400, Train Cost: 0.296	Val Cost: 0.330
# Epoch 500, Train Cost: 0.287	Val Cost: 0.328
# Epoch 600, Train Cost: 0.279	Val Cost: 0.328
# Epoch 700, Train Cost: 0.274	Val Cost: 0.330
# Epoch 800, Train Cost: 0.270	Val Cost: 0.332
# Epoch 900, Train Cost: 0.267	Val Cost: 0.334
#
# Test Cost: 0.298
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.759	Val Cost: 0.613
# Epoch 100, Train Cost: 0.276	Val Cost: 0.301
# Epoch 200, Train Cost: 0.167	Val Cost: 0.218
# Epoch 300, Train Cost: 0.146	Val Cost: 0.248
# Epoch 400, Train Cost: 0.128	Val Cost: 0.256
# Epoch 500, Train Cost: 0.117	Val Cost: 0.266
# Epoch 600, Train Cost: 0.108	Val Cost: 0.277
# Epoch 700, Train Cost: 0.102	Val Cost: 0.289
# Epoch 800, Train Cost: 0.096	Val Cost: 0.301
# Epoch 900, Train Cost: 0.092	Val Cost: 0.314
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.807	Val Cost: 0.630
# Epoch 100, Train Cost: 0.268	Val Cost: 0.294
# Epoch 200, Train Cost: 0.158	Val Cost: 0.211
# Epoch 300, Train Cost: 0.145	Val Cost: 0.249
# Epoch 400, Train Cost: 0.127	Val Cost: 0.257
# Epoch 500, Train Cost: 0.116	Val Cost: 0.267
# Epoch 600, Train Cost: 0.108	Val Cost: 0.278
# Epoch 700, Train Cost: 0.101	Val Cost: 0.289
# Epoch 800, Train Cost: 0.096	Val Cost: 0.302
# Epoch 900, Train Cost: 0.092	Val Cost: 0.315
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.882	Val Cost: 0.712
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.307	Val Cost: 0.332
# Epoch 400, Train Cost: 0.301	Val Cost: 0.333
# Epoch 500, Train Cost: 0.292	Val Cost: 0.331
# Epoch 600, Train Cost: 0.283	Val Cost: 0.330
# Epoch 700, Train Cost: 0.277	Val Cost: 0.330
# Epoch 800, Train Cost: 0.272	Val Cost: 0.330
# Epoch 900, Train Cost: 0.269	Val Cost: 0.331
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.689	Val Cost: 0.590
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.305	Val Cost: 0.334
# Epoch 400, Train Cost: 0.301	Val Cost: 0.333
# Epoch 500, Train Cost: 0.292	Val Cost: 0.331
# Epoch 600, Train Cost: 0.283	Val Cost: 0.330
# Epoch 700, Train Cost: 0.277	Val Cost: 0.330
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.294
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.831	Val Cost: 0.737
# Epoch 100, Train Cost: 0.315	Val Cost: 0.339
# Epoch 200, Train Cost: 0.328	Val Cost: 0.374
# Epoch 300, Train Cost: 0.252	Val Cost: 0.288
# Epoch 400, Train Cost: 0.176	Val Cost: 0.245
# Epoch 500, Train Cost: 0.145	Val Cost: 0.245
# Epoch 600, Train Cost: 0.127	Val Cost: 0.255
# Epoch 700, Train Cost: 0.116	Val Cost: 0.265
# Epoch 800, Train Cost: 0.108	Val Cost: 0.277
# Epoch 900, Train Cost: 0.101	Val Cost: 0.288
#
# Test Cost: 0.096
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.561	Val Cost: 0.518
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.316	Val Cost: 0.351
# Epoch 300, Train Cost: 0.306	Val Cost: 0.336
# Epoch 400, Train Cost: 0.301	Val Cost: 0.334
# Epoch 500, Train Cost: 0.294	Val Cost: 0.335
# Epoch 600, Train Cost: 0.287	Val Cost: 0.335
# Epoch 700, Train Cost: 0.280	Val Cost: 0.333
# Epoch 800, Train Cost: 0.275	Val Cost: 0.330
# Epoch 900, Train Cost: 0.270	Val Cost: 0.328
#
# Test Cost: 0.291
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.629	Val Cost: 0.596
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.399	Val Cost: 0.380
# Epoch 300, Train Cost: 0.309	Val Cost: 0.331
# Epoch 400, Train Cost: 0.301	Val Cost: 0.331
# Epoch 500, Train Cost: 0.292	Val Cost: 0.328
# Epoch 600, Train Cost: 0.283	Val Cost: 0.327
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.717	Val Cost: 0.564
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.318	Val Cost: 0.332
# Epoch 300, Train Cost: 0.304	Val Cost: 0.323
# Epoch 400, Train Cost: 0.298	Val Cost: 0.318
# Epoch 500, Train Cost: 0.294	Val Cost: 0.315
# Epoch 600, Train Cost: 0.291	Val Cost: 0.314
# Epoch 700, Train Cost: 0.289	Val Cost: 0.313
# Epoch 800, Train Cost: 0.288	Val Cost: 0.312
# Epoch 900, Train Cost: 0.286	Val Cost: 0.312
#
# Test Cost: 0.258
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.360	Val Cost: 0.367
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.333
# Epoch 300, Train Cost: 0.317	Val Cost: 0.334
# Epoch 400, Train Cost: 0.309	Val Cost: 0.331
# Epoch 500, Train Cost: 0.304	Val Cost: 0.333
# Epoch 600, Train Cost: 0.297	Val Cost: 0.332
# Epoch 700, Train Cost: 0.288	Val Cost: 0.331
# Epoch 800, Train Cost: 0.280	Val Cost: 0.329
# Epoch 900, Train Cost: 0.275	Val Cost: 0.328
#
# Test Cost: 0.284
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.486	Val Cost: 0.467
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.335
# Epoch 400, Train Cost: 0.302	Val Cost: 0.332
# Epoch 500, Train Cost: 0.293	Val Cost: 0.329
# Epoch 600, Train Cost: 0.283	Val Cost: 0.328
# Epoch 700, Train Cost: 0.277	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.330
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.294
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.664	Val Cost: 0.521
# Epoch 100, Train Cost: 0.238	Val Cost: 0.271
# Epoch 200, Train Cost: 0.150	Val Cost: 0.213
# Epoch 300, Train Cost: 0.139	Val Cost: 0.252
# Epoch 400, Train Cost: 0.124	Val Cost: 0.260
# Epoch 500, Train Cost: 0.114	Val Cost: 0.270
# Epoch 600, Train Cost: 0.106	Val Cost: 0.281
# Epoch 700, Train Cost: 0.100	Val Cost: 0.293
# Epoch 800, Train Cost: 0.095	Val Cost: 0.306
# Epoch 900, Train Cost: 0.091	Val Cost: 0.320
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.506	Val Cost: 0.444
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.306	Val Cost: 0.334
# Epoch 300, Train Cost: 0.301	Val Cost: 0.332
# Epoch 400, Train Cost: 0.291	Val Cost: 0.330
# Epoch 500, Train Cost: 0.282	Val Cost: 0.329
# Epoch 600, Train Cost: 0.276	Val Cost: 0.329
# Epoch 700, Train Cost: 0.272	Val Cost: 0.330
# Epoch 800, Train Cost: 0.269	Val Cost: 0.331
# Epoch 900, Train Cost: 0.266	Val Cost: 0.332
#
# Test Cost: 0.302
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.636	Val Cost: 0.614
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.307	Val Cost: 0.334
# Epoch 400, Train Cost: 0.302	Val Cost: 0.333
# Epoch 500, Train Cost: 0.294	Val Cost: 0.331
# Epoch 600, Train Cost: 0.285	Val Cost: 0.330
# Epoch 700, Train Cost: 0.278	Val Cost: 0.329
# Epoch 800, Train Cost: 0.273	Val Cost: 0.329
# Epoch 900, Train Cost: 0.269	Val Cost: 0.330
#
# Test Cost: 0.293
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.752	Val Cost: 0.706
# Epoch 100, Train Cost: 0.302	Val Cost: 0.330
# Epoch 200, Train Cost: 0.308	Val Cost: 0.356
# Epoch 300, Train Cost: 0.301	Val Cost: 0.347
# Epoch 400, Train Cost: 0.297	Val Cost: 0.341
# Epoch 500, Train Cost: 0.294	Val Cost: 0.337
# Epoch 600, Train Cost: 0.292	Val Cost: 0.334
# Epoch 700, Train Cost: 0.291	Val Cost: 0.332
# Epoch 800, Train Cost: 0.290	Val Cost: 0.331
# Epoch 900, Train Cost: 0.289	Val Cost: 0.330
#
# Test Cost: 0.232
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.984	Val Cost: 0.484
# Epoch 100, Train Cost: 0.308	Val Cost: 0.335
# Epoch 200, Train Cost: 0.303	Val Cost: 0.334
# Epoch 300, Train Cost: 0.296	Val Cost: 0.332
# Epoch 400, Train Cost: 0.287	Val Cost: 0.331
# Epoch 500, Train Cost: 0.279	Val Cost: 0.329
# Epoch 600, Train Cost: 0.274	Val Cost: 0.328
# Epoch 700, Train Cost: 0.270	Val Cost: 0.329
# Epoch 800, Train Cost: 0.267	Val Cost: 0.329
# Epoch 900, Train Cost: 0.265	Val Cost: 0.330
#
# Test Cost: 0.305
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.597	Val Cost: 0.524
# Epoch 100, Train Cost: 0.284	Val Cost: 0.308
# Epoch 200, Train Cost: 0.261	Val Cost: 0.351
# Epoch 300, Train Cost: 0.147	Val Cost: 0.249
# Epoch 400, Train Cost: 0.129	Val Cost: 0.256
# Epoch 500, Train Cost: 0.117	Val Cost: 0.266
# Epoch 600, Train Cost: 0.108	Val Cost: 0.277
# Epoch 700, Train Cost: 0.102	Val Cost: 0.289
# Epoch 800, Train Cost: 0.097	Val Cost: 0.301
# Epoch 900, Train Cost: 0.092	Val Cost: 0.314
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.685	Val Cost: 0.568
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.305	Val Cost: 0.334
# Epoch 400, Train Cost: 0.298	Val Cost: 0.332
# Epoch 500, Train Cost: 0.289	Val Cost: 0.330
# Epoch 600, Train Cost: 0.280	Val Cost: 0.329
# Epoch 700, Train Cost: 0.275	Val Cost: 0.330
# Epoch 800, Train Cost: 0.271	Val Cost: 0.331
# Epoch 900, Train Cost: 0.268	Val Cost: 0.332
#
# Test Cost: 0.297
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.753	Val Cost: 0.662
# Epoch 100, Train Cost: 0.309	Val Cost: 0.335
# Epoch 200, Train Cost: 0.303	Val Cost: 0.332
# Epoch 300, Train Cost: 0.293	Val Cost: 0.329
# Epoch 400, Train Cost: 0.283	Val Cost: 0.327
# Epoch 500, Train Cost: 0.277	Val Cost: 0.328
# Epoch 600, Train Cost: 0.272	Val Cost: 0.329
# Epoch 700, Train Cost: 0.269	Val Cost: 0.330
# Epoch 800, Train Cost: 0.267	Val Cost: 0.331
# Epoch 900, Train Cost: 0.265	Val Cost: 0.333
#
# Test Cost: 0.307
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.635	Val Cost: 0.614
# Epoch 100, Train Cost: 0.220	Val Cost: 0.255
# Epoch 200, Train Cost: 0.138	Val Cost: 0.199
# Epoch 300, Train Cost: 0.148	Val Cost: 0.217
# Epoch 400, Train Cost: 0.135	Val Cost: 0.223
# Epoch 500, Train Cost: 0.126	Val Cost: 0.233
# Epoch 600, Train Cost: 0.119	Val Cost: 0.244
# Epoch 700, Train Cost: 0.113	Val Cost: 0.256
# Epoch 800, Train Cost: 0.109	Val Cost: 0.268
# Epoch 900, Train Cost: 0.105	Val Cost: 0.282
#
# Test Cost: 0.124
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.740	Val Cost: 0.685
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.312	Val Cost: 0.359
# Epoch 300, Train Cost: 0.301	Val Cost: 0.347
# Epoch 400, Train Cost: 0.295	Val Cost: 0.342
# Epoch 500, Train Cost: 0.292	Val Cost: 0.338
# Epoch 600, Train Cost: 0.289	Val Cost: 0.336
# Epoch 700, Train Cost: 0.288	Val Cost: 0.335
# Epoch 800, Train Cost: 0.286	Val Cost: 0.334
# Epoch 900, Train Cost: 0.285	Val Cost: 0.333
#
# Test Cost: 0.241
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.793	Val Cost: 0.636
# Epoch 100, Train Cost: 0.238	Val Cost: 0.268
# Epoch 200, Train Cost: 0.147	Val Cost: 0.203
# Epoch 300, Train Cost: 0.153	Val Cost: 0.216
# Epoch 400, Train Cost: 0.137	Val Cost: 0.221
# Epoch 500, Train Cost: 0.127	Val Cost: 0.231
# Epoch 600, Train Cost: 0.120	Val Cost: 0.242
# Epoch 700, Train Cost: 0.114	Val Cost: 0.253
# Epoch 800, Train Cost: 0.109	Val Cost: 0.266
# Epoch 900, Train Cost: 0.106	Val Cost: 0.279
#
# Test Cost: 0.125
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.329	Val Cost: 0.660
# Epoch 100, Train Cost: 0.309	Val Cost: 0.334
# Epoch 200, Train Cost: 0.305	Val Cost: 0.336
# Epoch 300, Train Cost: 0.300	Val Cost: 0.337
# Epoch 400, Train Cost: 0.295	Val Cost: 0.339
# Epoch 500, Train Cost: 0.288	Val Cost: 0.341
# Epoch 600, Train Cost: 0.282	Val Cost: 0.341
# Epoch 700, Train Cost: 0.278	Val Cost: 0.340
# Epoch 800, Train Cost: 0.274	Val Cost: 0.338
# Epoch 900, Train Cost: 0.270	Val Cost: 0.332
#
# Test Cost: 0.294
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.453	Val Cost: 0.438
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.305	Val Cost: 0.334
# Epoch 400, Train Cost: 0.299	Val Cost: 0.333
# Epoch 500, Train Cost: 0.290	Val Cost: 0.331
# Epoch 600, Train Cost: 0.282	Val Cost: 0.330
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.271	Val Cost: 0.329
# Epoch 900, Train Cost: 0.268	Val Cost: 0.330
#
# Test Cost: 0.296
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.863	Val Cost: 0.636
# Epoch 100, Train Cost: 0.301	Val Cost: 0.330
# Epoch 200, Train Cost: 0.311	Val Cost: 0.325
# Epoch 300, Train Cost: 0.304	Val Cost: 0.317
# Epoch 400, Train Cost: 0.300	Val Cost: 0.313
# Epoch 500, Train Cost: 0.297	Val Cost: 0.310
# Epoch 600, Train Cost: 0.295	Val Cost: 0.308
# Epoch 700, Train Cost: 0.294	Val Cost: 0.306
# Epoch 800, Train Cost: 0.293	Val Cost: 0.305
# Epoch 900, Train Cost: 0.292	Val Cost: 0.305
#
# Test Cost: 0.262
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.720	Val Cost: 0.572
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.303	Val Cost: 0.333
# Epoch 400, Train Cost: 0.295	Val Cost: 0.330
# Epoch 500, Train Cost: 0.286	Val Cost: 0.329
# Epoch 600, Train Cost: 0.278	Val Cost: 0.329
# Epoch 700, Train Cost: 0.273	Val Cost: 0.330
# Epoch 800, Train Cost: 0.270	Val Cost: 0.332
# Epoch 900, Train Cost: 0.267	Val Cost: 0.333
#
# Test Cost: 0.299
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.585	Val Cost: 0.496
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.303	Val Cost: 0.334
# Epoch 300, Train Cost: 0.293	Val Cost: 0.331
# Epoch 400, Train Cost: 0.284	Val Cost: 0.329
# Epoch 500, Train Cost: 0.277	Val Cost: 0.328
# Epoch 600, Train Cost: 0.273	Val Cost: 0.328
# Epoch 700, Train Cost: 0.269	Val Cost: 0.328
# Epoch 800, Train Cost: 0.267	Val Cost: 0.329
# Epoch 900, Train Cost: 0.265	Val Cost: 0.330
#
# Test Cost: 0.306
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.613	Val Cost: 0.546
# Epoch 100, Train Cost: 0.309	Val Cost: 0.336
# Epoch 200, Train Cost: 0.302	Val Cost: 0.334
# Epoch 300, Train Cost: 0.294	Val Cost: 0.333
# Epoch 400, Train Cost: 0.285	Val Cost: 0.331
# Epoch 500, Train Cost: 0.278	Val Cost: 0.329
# Epoch 600, Train Cost: 0.273	Val Cost: 0.328
# Epoch 700, Train Cost: 0.269	Val Cost: 0.328
# Epoch 800, Train Cost: 0.267	Val Cost: 0.329
# Epoch 900, Train Cost: 0.265	Val Cost: 0.329
#
# Test Cost: 0.306
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.139	Val Cost: 0.735
# Epoch 100, Train Cost: 0.311	Val Cost: 0.337
# Epoch 200, Train Cost: 0.305	Val Cost: 0.334
# Epoch 300, Train Cost: 0.296	Val Cost: 0.331
# Epoch 400, Train Cost: 0.286	Val Cost: 0.329
# Epoch 500, Train Cost: 0.279	Val Cost: 0.328
# Epoch 600, Train Cost: 0.274	Val Cost: 0.328
# Epoch 700, Train Cost: 0.270	Val Cost: 0.329
# Epoch 800, Train Cost: 0.267	Val Cost: 0.330
# Epoch 900, Train Cost: 0.265	Val Cost: 0.331
#
# Test Cost: 0.305
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.665	Val Cost: 0.573
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.314	Val Cost: 0.348
# Epoch 400, Train Cost: 0.307	Val Cost: 0.335
# Epoch 500, Train Cost: 0.302	Val Cost: 0.332
# Epoch 600, Train Cost: 0.293	Val Cost: 0.330
# Epoch 700, Train Cost: 0.284	Val Cost: 0.329
# Epoch 800, Train Cost: 0.277	Val Cost: 0.329
# Epoch 900, Train Cost: 0.273	Val Cost: 0.329
#
# Test Cost: 0.287
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.767	Val Cost: 0.683
# Epoch 100, Train Cost: 0.314	Val Cost: 0.336
# Epoch 200, Train Cost: 0.216	Val Cost: 0.256
# Epoch 300, Train Cost: 0.165	Val Cost: 0.246
# Epoch 400, Train Cost: 0.139	Val Cost: 0.249
# Epoch 500, Train Cost: 0.124	Val Cost: 0.259
# Epoch 600, Train Cost: 0.113	Val Cost: 0.269
# Epoch 700, Train Cost: 0.106	Val Cost: 0.281
# Epoch 800, Train Cost: 0.100	Val Cost: 0.292
# Epoch 900, Train Cost: 0.095	Val Cost: 0.305
#
# Test Cost: 0.094
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.748	Val Cost: 0.699
# Epoch 100, Train Cost: 0.310	Val Cost: 0.337
# Epoch 200, Train Cost: 0.304	Val Cost: 0.334
# Epoch 300, Train Cost: 0.295	Val Cost: 0.331
# Epoch 400, Train Cost: 0.285	Val Cost: 0.329
# Epoch 500, Train Cost: 0.278	Val Cost: 0.328
# Epoch 600, Train Cost: 0.273	Val Cost: 0.328
# Epoch 700, Train Cost: 0.270	Val Cost: 0.329
# Epoch 800, Train Cost: 0.267	Val Cost: 0.330
# Epoch 900, Train Cost: 0.265	Val Cost: 0.331
#
# Test Cost: 0.306
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.673	Val Cost: 0.643
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.314	Val Cost: 0.333
# Epoch 400, Train Cost: 0.305	Val Cost: 0.333
# Epoch 500, Train Cost: 0.299	Val Cost: 0.331
# Epoch 600, Train Cost: 0.290	Val Cost: 0.328
# Epoch 700, Train Cost: 0.281	Val Cost: 0.328
# Epoch 800, Train Cost: 0.275	Val Cost: 0.329
# Epoch 900, Train Cost: 0.271	Val Cost: 0.331
#
# Test Cost: 0.289
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.980	Val Cost: 0.675
# Epoch 100, Train Cost: 0.312	Val Cost: 0.337
# Epoch 200, Train Cost: 0.327	Val Cost: 0.337
# Epoch 300, Train Cost: 0.307	Val Cost: 0.331
# Epoch 400, Train Cost: 0.302	Val Cost: 0.333
# Epoch 500, Train Cost: 0.295	Val Cost: 0.334
# Epoch 600, Train Cost: 0.287	Val Cost: 0.335
# Epoch 700, Train Cost: 0.281	Val Cost: 0.333
# Epoch 800, Train Cost: 0.275	Val Cost: 0.330
# Epoch 900, Train Cost: 0.271	Val Cost: 0.328
#
# Test Cost: 0.291
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.514	Val Cost: 0.482
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.304	Val Cost: 0.333
# Epoch 400, Train Cost: 0.298	Val Cost: 0.334
# Epoch 500, Train Cost: 0.290	Val Cost: 0.334
# Epoch 600, Train Cost: 0.283	Val Cost: 0.333
# Epoch 700, Train Cost: 0.276	Val Cost: 0.330
# Epoch 800, Train Cost: 0.272	Val Cost: 0.329
# Epoch 900, Train Cost: 0.269	Val Cost: 0.329
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.529	Val Cost: 0.433
# Epoch 100, Train Cost: 0.308	Val Cost: 0.335
# Epoch 200, Train Cost: 0.304	Val Cost: 0.335
# Epoch 300, Train Cost: 0.298	Val Cost: 0.336
# Epoch 400, Train Cost: 0.292	Val Cost: 0.338
# Epoch 500, Train Cost: 0.285	Val Cost: 0.338
# Epoch 600, Train Cost: 0.279	Val Cost: 0.337
# Epoch 700, Train Cost: 0.274	Val Cost: 0.333
# Epoch 800, Train Cost: 0.270	Val Cost: 0.331
# Epoch 900, Train Cost: 0.267	Val Cost: 0.331
#
# Test Cost: 0.300
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.762	Val Cost: 0.673
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.304	Val Cost: 0.334
# Epoch 400, Train Cost: 0.299	Val Cost: 0.334
# Epoch 500, Train Cost: 0.291	Val Cost: 0.334
# Epoch 600, Train Cost: 0.283	Val Cost: 0.333
# Epoch 700, Train Cost: 0.277	Val Cost: 0.331
# Epoch 800, Train Cost: 0.272	Val Cost: 0.329
# Epoch 900, Train Cost: 0.269	Val Cost: 0.330
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.264	Val Cost: 0.739
# Epoch 100, Train Cost: 0.256	Val Cost: 0.284
# Epoch 200, Train Cost: 0.153	Val Cost: 0.208
# Epoch 300, Train Cost: 0.143	Val Cost: 0.249
# Epoch 400, Train Cost: 0.126	Val Cost: 0.257
# Epoch 500, Train Cost: 0.115	Val Cost: 0.268
# Epoch 600, Train Cost: 0.107	Val Cost: 0.279
# Epoch 700, Train Cost: 0.101	Val Cost: 0.291
# Epoch 800, Train Cost: 0.096	Val Cost: 0.303
# Epoch 900, Train Cost: 0.092	Val Cost: 0.316
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.084	Val Cost: 0.769
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.334
# Epoch 300, Train Cost: 0.308	Val Cost: 0.338
# Epoch 400, Train Cost: 0.303	Val Cost: 0.333
# Epoch 500, Train Cost: 0.297	Val Cost: 0.332
# Epoch 600, Train Cost: 0.288	Val Cost: 0.331
# Epoch 700, Train Cost: 0.280	Val Cost: 0.330
# Epoch 800, Train Cost: 0.275	Val Cost: 0.328
# Epoch 900, Train Cost: 0.271	Val Cost: 0.328
#
# Test Cost: 0.291
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.805	Val Cost: 0.536
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.334
# Epoch 300, Train Cost: 0.301	Val Cost: 0.333
# Epoch 400, Train Cost: 0.292	Val Cost: 0.331
# Epoch 500, Train Cost: 0.283	Val Cost: 0.329
# Epoch 600, Train Cost: 0.276	Val Cost: 0.329
# Epoch 700, Train Cost: 0.272	Val Cost: 0.329
# Epoch 800, Train Cost: 0.269	Val Cost: 0.330
# Epoch 900, Train Cost: 0.266	Val Cost: 0.331
#
# Test Cost: 0.301
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.569	Val Cost: 0.542
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.307	Val Cost: 0.335
# Epoch 300, Train Cost: 0.304	Val Cost: 0.334
# Epoch 400, Train Cost: 0.297	Val Cost: 0.332
# Epoch 500, Train Cost: 0.288	Val Cost: 0.331
# Epoch 600, Train Cost: 0.280	Val Cost: 0.330
# Epoch 700, Train Cost: 0.275	Val Cost: 0.330
# Epoch 800, Train Cost: 0.271	Val Cost: 0.330
# Epoch 900, Train Cost: 0.268	Val Cost: 0.331
#
# Test Cost: 0.297
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.728	Val Cost: 0.506
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.380	Val Cost: 0.534
# Epoch 300, Train Cost: 0.310	Val Cost: 0.343
# Epoch 400, Train Cost: 0.302	Val Cost: 0.332
# Epoch 500, Train Cost: 0.293	Val Cost: 0.329
# Epoch 600, Train Cost: 0.284	Val Cost: 0.328
# Epoch 700, Train Cost: 0.277	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.294
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.638	Val Cost: 0.562
# Epoch 100, Train Cost: 0.278	Val Cost: 0.303
# Epoch 200, Train Cost: 0.190	Val Cost: 0.222
# Epoch 300, Train Cost: 0.156	Val Cost: 0.215
# Epoch 400, Train Cost: 0.140	Val Cost: 0.220
# Epoch 500, Train Cost: 0.129	Val Cost: 0.229
# Epoch 600, Train Cost: 0.121	Val Cost: 0.239
# Epoch 700, Train Cost: 0.115	Val Cost: 0.251
# Epoch 800, Train Cost: 0.110	Val Cost: 0.263
# Epoch 900, Train Cost: 0.106	Val Cost: 0.276
#
# Test Cost: 0.125
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.703	Val Cost: 0.694
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.334
# Epoch 300, Train Cost: 0.305	Val Cost: 0.334
# Epoch 400, Train Cost: 0.299	Val Cost: 0.333
# Epoch 500, Train Cost: 0.291	Val Cost: 0.332
# Epoch 600, Train Cost: 0.282	Val Cost: 0.330
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.329
# Epoch 900, Train Cost: 0.269	Val Cost: 0.330
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.828	Val Cost: 0.591
# Epoch 100, Train Cost: 0.308	Val Cost: 0.334
# Epoch 200, Train Cost: 0.301	Val Cost: 0.331
# Epoch 300, Train Cost: 0.291	Val Cost: 0.328
# Epoch 400, Train Cost: 0.282	Val Cost: 0.327
# Epoch 500, Train Cost: 0.276	Val Cost: 0.327
# Epoch 600, Train Cost: 0.272	Val Cost: 0.328
# Epoch 700, Train Cost: 0.269	Val Cost: 0.329
# Epoch 800, Train Cost: 0.266	Val Cost: 0.331
# Epoch 900, Train Cost: 0.264	Val Cost: 0.332
#
# Test Cost: 0.308
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.615	Val Cost: 0.595
# Epoch 100, Train Cost: 0.310	Val Cost: 0.333
# Epoch 200, Train Cost: 0.215	Val Cost: 0.268
# Epoch 300, Train Cost: 0.160	Val Cost: 0.247
# Epoch 400, Train Cost: 0.136	Val Cost: 0.251
# Epoch 500, Train Cost: 0.122	Val Cost: 0.261
# Epoch 600, Train Cost: 0.112	Val Cost: 0.271
# Epoch 700, Train Cost: 0.105	Val Cost: 0.283
# Epoch 800, Train Cost: 0.099	Val Cost: 0.295
# Epoch 900, Train Cost: 0.094	Val Cost: 0.307
#
# Test Cost: 0.094
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.940	Val Cost: 0.635
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.334
# Epoch 300, Train Cost: 0.306	Val Cost: 0.336
# Epoch 400, Train Cost: 0.300	Val Cost: 0.331
# Epoch 500, Train Cost: 0.291	Val Cost: 0.329
# Epoch 600, Train Cost: 0.282	Val Cost: 0.328
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.333
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.660	Val Cost: 0.622
# Epoch 100, Train Cost: 0.214	Val Cost: 0.251
# Epoch 200, Train Cost: 0.203	Val Cost: 0.463
# Epoch 300, Train Cost: 0.136	Val Cost: 0.252
# Epoch 400, Train Cost: 0.122	Val Cost: 0.261
# Epoch 500, Train Cost: 0.112	Val Cost: 0.272
# Epoch 600, Train Cost: 0.105	Val Cost: 0.283
# Epoch 700, Train Cost: 0.099	Val Cost: 0.295
# Epoch 800, Train Cost: 0.094	Val Cost: 0.308
# Epoch 900, Train Cost: 0.091	Val Cost: 0.322
#
# Test Cost: 0.093
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.528	Val Cost: 0.469
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.304	Val Cost: 0.334
# Epoch 300, Train Cost: 0.297	Val Cost: 0.333
# Epoch 400, Train Cost: 0.288	Val Cost: 0.331
# Epoch 500, Train Cost: 0.280	Val Cost: 0.329
# Epoch 600, Train Cost: 0.274	Val Cost: 0.328
# Epoch 700, Train Cost: 0.271	Val Cost: 0.328
# Epoch 800, Train Cost: 0.268	Val Cost: 0.329
# Epoch 900, Train Cost: 0.266	Val Cost: 0.330
#
# Test Cost: 0.304
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.155	Val Cost: 0.717
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.313	Val Cost: 0.333
# Epoch 400, Train Cost: 0.306	Val Cost: 0.333
# Epoch 500, Train Cost: 0.301	Val Cost: 0.332
# Epoch 600, Train Cost: 0.292	Val Cost: 0.330
# Epoch 700, Train Cost: 0.283	Val Cost: 0.329
# Epoch 800, Train Cost: 0.276	Val Cost: 0.329
# Epoch 900, Train Cost: 0.272	Val Cost: 0.329
#
# Test Cost: 0.288
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.689	Val Cost: 0.584
# Epoch 100, Train Cost: 0.311	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.333
# Epoch 400, Train Cost: 0.301	Val Cost: 0.332
# Epoch 500, Train Cost: 0.292	Val Cost: 0.329
# Epoch 600, Train Cost: 0.283	Val Cost: 0.328
# Epoch 700, Train Cost: 0.277	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.295
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.862	Val Cost: 0.660
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.305	Val Cost: 0.334
# Epoch 300, Train Cost: 0.299	Val Cost: 0.334
# Epoch 400, Train Cost: 0.290	Val Cost: 0.333
# Epoch 500, Train Cost: 0.282	Val Cost: 0.331
# Epoch 600, Train Cost: 0.276	Val Cost: 0.329
# Epoch 700, Train Cost: 0.272	Val Cost: 0.328
# Epoch 800, Train Cost: 0.268	Val Cost: 0.329
# Epoch 900, Train Cost: 0.266	Val Cost: 0.329
#
# Test Cost: 0.302

# %%
plt.subplot(121)
plt.plot(test_errors)
plt.xlabel('Initialization number')
plt.ylabel('Test cost')
plt.subplot(122)
plt.hist(test_errors,bins=50,normed=True);
plt.axvline(x=0.270,c='r')
plt.xlabel('Test cost')
plt.ylabel('Frequency')

# %%
density,bins = np.histogram(test_errors,bins=n_runs,normed=True)
cdf = np.cumsum(density)
cdf /= cdf[-1]

# %%
print('With 2 hidden units in 1 layer, the test cost is worse in %d %% of the initializations' % (np.where(cdf > 0.27)[0][0]))
# Out:
# With 2 hidden units in 1 layer, the test cost is worse in 67 % of the initializations

# %% [markdown]
# 2) Experiment with multiple hidden layers or more / less hidden units. What happens to the decision boundary?

# %% [markdown]
# #### More hidden units

# %%
from multiprocess import Pool
p = Pool(16)

# %%
# %time test_errors = [p.map(lambda h: train_network(num_hidden_units=h), range(2,10)) for i in range(10)]
# Out:
# CPU times: user 324 ms, sys: 160 ms, total: 484 ms
# Wall time: 5.66 s

# %%
test_errors = np.array(test_errors)

# %%
test_errors.shape
# Out:
# (10, 8)

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
mean_test_error = test_errors[:,:].mean(axis=0)
std_test_error = test_errors[:,:].std(axis=0)
plt.plot(range(2,10), mean_test_error)
plt.fill_between(range(2,10), mean_test_error-std_test_error, mean_test_error+std_test_error,color='k',alpha=0.1)
plt.xlabel('Number of hidden units in layer')
plt.ylabel('Mean test cost +- standard deviation across 10 initializations')

# %% [markdown]
# #### More hidden layers

# %%
def train_network(n_epochs = 1000, num_hidden_units = [2], verbose = True, draw = False):
    #MODEL SPECIFICATION
    l_in = InputLayer(shape=(None, num_features))
    #INSERT HIDDEN LAYER HERE
    #l = DenseLayer(incoming=l,.....
    hidden_layers = [DenseLayer(incoming=l_in, num_units=num_hidden_units[0], nonlinearity=tanh, name='hidden')]
    for num_hidden_unit in num_hidden_units[1:]:
        hidden_layers.append(DenseLayer(incoming=hidden_layers[-1], num_units=num_hidden_unit, nonlinearity=tanh, name='hidden'))
    l_out = DenseLayer(incoming=hidden_layers[-1], num_units=2, nonlinearity=softmax, name='outputlayer') 
    #We use two output units since we have two classes. The softmax function ensures that the the class probabilities sum to 1.
    # Get network output
    train_out = lasagne.layers.get_output(l_out, {l_in: sym_x}, deterministic=False)
    eval_out = lasagne.layers.get_output(l_out, {l_in: sym_x}, deterministic=True)
    # Get list of all trainable parameters in the network.
    all_params = lasagne.layers.get_all_params(l_out, trainable=True)
    # print shapes of all the parameters in the network.
    for p in all_params:
        print(p, p.get_value().shape)
    cost_train = T.nnet.categorical_crossentropy(train_out, sym_t).mean()
    cost_eval = T.nnet.categorical_crossentropy(eval_out, sym_t).mean()
    # Let Theano do its magic and get all the gradients we need for training. Essentially T.grad does backprop i.e. get the 
    # gradient of cost_train w.r.t. the parameters.
    all_grads = T.grad(cost_train, all_params)
    # Set the update function for parameters 
    # you might want to experiment with more advanded update schemes like rmsprob, adadelta etc.
    updates = lasagne.updates.sgd(all_grads, all_params, learning_rate=1.0)
    f_eval = theano.function(inputs=[sym_x, sym_t],
                             outputs=[cost_eval, eval_out])
    f_train = theano.function(inputs=[sym_x, sym_t],
                              outputs=[cost_train, eval_out],
                              updates=updates)
    #now you have three functions. 
    # f_train(X,y) -> cost, y_pred which will update the parameters using backprop each time you call it, only use this on the training data!
    # f_test(X,y) -> cost, y_pred which only calculates the forward pass
    #This us just a helper function for plotting the decision boundaries between the two classes
    f_pred = theano.function(inputs=[sym_x],
                             outputs=eval_out)
    if draw:
        # Training loop
        plot_decision_boundary(lambda x: f_pred(x), X_val,y_val)
        plt.title("Untrained Classifier")
        plt.colorbar()
    train_cost, val_cost = [],[]
    for e in range(num_epochs):
        out = f_train(X_tr,y_tr)
        #out = [cost, y_pred]
        train_cost += [out[0]]
        out = f_eval(X_val,y_val)
        val_cost += [out[0]]
        if verbose:
            if e % 100 == 0:
                print("Epoch %i, Train Cost: %0.3f\tVal Cost: %0.3f"%(e, train_cost[-1],val_cost[-1]))
    out = f_eval(X_te,y_te)
    test_cost = out[0]
    if verbose:
        print("\nTest Cost: %0.3f"%(test_cost))
    
    if draw:
        plot_decision_boundary(lambda x: f_pred(x), X_te, y_te)
        plt.title("Trained Classifier")
        plt.colorbar()
        epoch = np.arange(len(train_cost))
        plt.figure()
        plt.plot(epoch,train_cost,'r',epoch,val_cost,'b')
        plt.legend(['Train Loss','Val Loss'])
        plt.xlabel('Updates'), plt.ylabel('Loss')
    return (train_cost[-1],val_cost[-1],test_cost)

# %%
# %%time
n_runs = 10
num_hidden_layers = 10
architectures = [list(range(2,i))[::-1] for i in range(3,num_hidden_layers)]
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 60.1 µs

# %%
architectures
# Out:
# [[2],
#  [3, 2],
#  [4, 3, 2],
#  [5, 4, 3, 2],
#  [6, 5, 4, 3, 2],
#  [7, 6, 5, 4, 3, 2],
#  [8, 7, 6, 5, 4, 3, 2]]

# %%
# %%time
test_errors = [[train_network(num_hidden_units = architecture) for architecture in architectures] for i in range(30)]
# Out:
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.589	Val Cost: 0.558
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.333
# Epoch 400, Train Cost: 0.301	Val Cost: 0.332
# Epoch 500, Train Cost: 0.291	Val Cost: 0.329
# Epoch 600, Train Cost: 0.283	Val Cost: 0.328
# Epoch 700, Train Cost: 0.276	Val Cost: 0.329
# Epoch 800, Train Cost: 0.272	Val Cost: 0.331
# Epoch 900, Train Cost: 0.269	Val Cost: 0.332
#
# Test Cost: 0.295
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.782	Val Cost: 0.667
# Epoch 100, Train Cost: 0.339	Val Cost: 0.353
# Epoch 200, Train Cost: 0.275	Val Cost: 0.314
# Epoch 300, Train Cost: 0.261	Val Cost: 0.304
# Epoch 400, Train Cost: 0.255	Val Cost: 0.304
# Epoch 500, Train Cost: 0.252	Val Cost: 0.305
# Epoch 600, Train Cost: 0.250	Val Cost: 0.307
# Epoch 700, Train Cost: 0.248	Val Cost: 0.310
# Epoch 800, Train Cost: 0.243	Val Cost: 0.312
# Epoch 900, Train Cost: 0.223	Val Cost: 0.308
#
# Test Cost: 0.330
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.642	Val Cost: 0.597
# Epoch 100, Train Cost: 0.184	Val Cost: 0.219
# Epoch 200, Train Cost: 0.023	Val Cost: 0.167
# Epoch 300, Train Cost: 0.004	Val Cost: 0.189
# Epoch 400, Train Cost: 0.002	Val Cost: 0.205
# Epoch 500, Train Cost: 0.001	Val Cost: 0.217
# Epoch 600, Train Cost: 0.001	Val Cost: 0.225
# Epoch 700, Train Cost: 0.001	Val Cost: 0.231
# Epoch 800, Train Cost: 0.000	Val Cost: 0.236
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.125
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.652	Val Cost: 0.623
# Epoch 100, Train Cost: 0.325	Val Cost: 0.240
# Epoch 200, Train Cost: 0.144	Val Cost: 0.153
# Epoch 300, Train Cost: 0.008	Val Cost: 0.160
# Epoch 400, Train Cost: 0.003	Val Cost: 0.185
# Epoch 500, Train Cost: 0.002	Val Cost: 0.200
# Epoch 600, Train Cost: 0.001	Val Cost: 0.211
# Epoch 700, Train Cost: 0.001	Val Cost: 0.219
# Epoch 800, Train Cost: 0.001	Val Cost: 0.225
# Epoch 900, Train Cost: 0.001	Val Cost: 0.230
#
# Test Cost: 0.215
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.673	Val Cost: 0.622
# Epoch 100, Train Cost: 0.349	Val Cost: 0.373
# Epoch 200, Train Cost: 0.032	Val Cost: 0.142
# Epoch 300, Train Cost: 0.002	Val Cost: 0.187
# Epoch 400, Train Cost: 0.001	Val Cost: 0.205
# Epoch 500, Train Cost: 0.001	Val Cost: 0.216
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.000	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.236
# Epoch 900, Train Cost: 0.000	Val Cost: 0.240
#
# Test Cost: 0.100
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.826	Val Cost: 0.650
# Epoch 100, Train Cost: 0.322	Val Cost: 0.295
# Epoch 200, Train Cost: 0.122	Val Cost: 0.203
# Epoch 300, Train Cost: 0.027	Val Cost: 0.169
# Epoch 400, Train Cost: 0.004	Val Cost: 0.169
# Epoch 500, Train Cost: 0.002	Val Cost: 0.197
# Epoch 600, Train Cost: 0.001	Val Cost: 0.211
# Epoch 700, Train Cost: 0.001	Val Cost: 0.220
# Epoch 800, Train Cost: 0.001	Val Cost: 0.227
# Epoch 900, Train Cost: 0.000	Val Cost: 0.233
#
# Test Cost: 0.104
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.653	Val Cost: 0.589
# Epoch 100, Train Cost: 0.381	Val Cost: 0.307
# Epoch 200, Train Cost: 0.269	Val Cost: 0.324
# Epoch 300, Train Cost: 0.020	Val Cost: 0.184
# Epoch 400, Train Cost: 0.013	Val Cost: 0.179
# Epoch 500, Train Cost: 0.006	Val Cost: 0.171
# Epoch 600, Train Cost: 0.002	Val Cost: 0.196
# Epoch 700, Train Cost: 0.001	Val Cost: 0.210
# Epoch 800, Train Cost: 0.001	Val Cost: 0.219
# Epoch 900, Train Cost: 0.001	Val Cost: 0.226
#
# Test Cost: 0.091
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.528	Val Cost: 0.484
# Epoch 100, Train Cost: 0.302	Val Cost: 0.330
# Epoch 200, Train Cost: 0.305	Val Cost: 0.351
# Epoch 300, Train Cost: 0.298	Val Cost: 0.344
# Epoch 400, Train Cost: 0.294	Val Cost: 0.339
# Epoch 500, Train Cost: 0.292	Val Cost: 0.336
# Epoch 600, Train Cost: 0.290	Val Cost: 0.334
# Epoch 700, Train Cost: 0.288	Val Cost: 0.333
# Epoch 800, Train Cost: 0.287	Val Cost: 0.331
# Epoch 900, Train Cost: 0.286	Val Cost: 0.331
#
# Test Cost: 0.238
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.715	Val Cost: 0.678
# Epoch 100, Train Cost: 0.189	Val Cost: 0.302
# Epoch 200, Train Cost: 0.020	Val Cost: 0.155
# Epoch 300, Train Cost: 0.012	Val Cost: 0.180
# Epoch 400, Train Cost: 0.003	Val Cost: 0.193
# Epoch 500, Train Cost: 0.002	Val Cost: 0.207
# Epoch 600, Train Cost: 0.001	Val Cost: 0.217
# Epoch 700, Train Cost: 0.001	Val Cost: 0.224
# Epoch 800, Train Cost: 0.001	Val Cost: 0.231
# Epoch 900, Train Cost: 0.001	Val Cost: 0.236
#
# Test Cost: 0.070
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.804	Val Cost: 0.639
# Epoch 100, Train Cost: 0.244	Val Cost: 0.229
# Epoch 200, Train Cost: 0.010	Val Cost: 0.176
# Epoch 300, Train Cost: 0.002	Val Cost: 0.190
# Epoch 400, Train Cost: 0.001	Val Cost: 0.203
# Epoch 500, Train Cost: 0.001	Val Cost: 0.212
# Epoch 600, Train Cost: 0.001	Val Cost: 0.219
# Epoch 700, Train Cost: 0.000	Val Cost: 0.224
# Epoch 800, Train Cost: 0.000	Val Cost: 0.229
# Epoch 900, Train Cost: 0.000	Val Cost: 0.233
#
# Test Cost: 0.147
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.616	Val Cost: 0.570
# Epoch 100, Train Cost: 0.416	Val Cost: 0.387
# Epoch 200, Train Cost: 0.021	Val Cost: 0.214
# Epoch 300, Train Cost: 0.007	Val Cost: 0.175
# Epoch 400, Train Cost: 0.002	Val Cost: 0.200
# Epoch 500, Train Cost: 0.001	Val Cost: 0.214
# Epoch 600, Train Cost: 0.001	Val Cost: 0.223
# Epoch 700, Train Cost: 0.001	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.236
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.130
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.673	Val Cost: 0.654
# Epoch 100, Train Cost: 0.289	Val Cost: 0.241
# Epoch 200, Train Cost: 0.013	Val Cost: 0.162
# Epoch 300, Train Cost: 0.002	Val Cost: 0.204
# Epoch 400, Train Cost: 0.001	Val Cost: 0.217
# Epoch 500, Train Cost: 0.001	Val Cost: 0.225
# Epoch 600, Train Cost: 0.001	Val Cost: 0.232
# Epoch 700, Train Cost: 0.000	Val Cost: 0.237
# Epoch 800, Train Cost: 0.000	Val Cost: 0.241
# Epoch 900, Train Cost: 0.000	Val Cost: 0.245
#
# Test Cost: 0.151
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.679	Val Cost: 0.531
# Epoch 100, Train Cost: 0.372	Val Cost: 0.339
# Epoch 200, Train Cost: 0.217	Val Cost: 0.216
# Epoch 300, Train Cost: 0.017	Val Cost: 0.166
# Epoch 400, Train Cost: 0.004	Val Cost: 0.170
# Epoch 500, Train Cost: 0.002	Val Cost: 0.197
# Epoch 600, Train Cost: 0.001	Val Cost: 0.211
# Epoch 700, Train Cost: 0.001	Val Cost: 0.220
# Epoch 800, Train Cost: 0.001	Val Cost: 0.227
# Epoch 900, Train Cost: 0.000	Val Cost: 0.233
#
# Test Cost: 0.089
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.758	Val Cost: 0.695
# Epoch 100, Train Cost: 0.388	Val Cost: 0.415
# Epoch 200, Train Cost: 0.196	Val Cost: 0.189
# Epoch 300, Train Cost: 0.059	Val Cost: 0.138
# Epoch 400, Train Cost: 0.002	Val Cost: 0.263
# Epoch 500, Train Cost: 0.001	Val Cost: 0.288
# Epoch 600, Train Cost: 0.001	Val Cost: 0.304
# Epoch 700, Train Cost: 0.001	Val Cost: 0.315
# Epoch 800, Train Cost: 0.000	Val Cost: 0.324
# Epoch 900, Train Cost: 0.000	Val Cost: 0.331
#
# Test Cost: 0.156
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.721	Val Cost: 0.492
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.306	Val Cost: 0.334
# Epoch 300, Train Cost: 0.300	Val Cost: 0.335
# Epoch 400, Train Cost: 0.294	Val Cost: 0.336
# Epoch 500, Train Cost: 0.286	Val Cost: 0.336
# Epoch 600, Train Cost: 0.280	Val Cost: 0.334
# Epoch 700, Train Cost: 0.274	Val Cost: 0.330
# Epoch 800, Train Cost: 0.270	Val Cost: 0.329
# Epoch 900, Train Cost: 0.267	Val Cost: 0.329
#
# Test Cost: 0.299
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.836	Val Cost: 0.668
# Epoch 100, Train Cost: 0.284	Val Cost: 0.278
# Epoch 200, Train Cost: 0.064	Val Cost: 0.145
# Epoch 300, Train Cost: 0.028	Val Cost: 0.170
# Epoch 400, Train Cost: 0.004	Val Cost: 0.184
# Epoch 500, Train Cost: 0.002	Val Cost: 0.199
# Epoch 600, Train Cost: 0.002	Val Cost: 0.210
# Epoch 700, Train Cost: 0.001	Val Cost: 0.218
# Epoch 800, Train Cost: 0.001	Val Cost: 0.225
# Epoch 900, Train Cost: 0.001	Val Cost: 0.230
#
# Test Cost: 0.073
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.578	Val Cost: 0.446
# Epoch 100, Train Cost: 0.323	Val Cost: 0.367
# Epoch 200, Train Cost: 0.234	Val Cost: 0.283
# Epoch 300, Train Cost: 0.159	Val Cost: 0.237
# Epoch 400, Train Cost: 0.254	Val Cost: 0.348
# Epoch 500, Train Cost: 0.013	Val Cost: 0.161
# Epoch 600, Train Cost: 0.004	Val Cost: 0.178
# Epoch 700, Train Cost: 0.002	Val Cost: 0.190
# Epoch 800, Train Cost: 0.001	Val Cost: 0.198
# Epoch 900, Train Cost: 0.001	Val Cost: 0.204
#
# Test Cost: 0.128
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.523	Val Cost: 0.427
# Epoch 100, Train Cost: 0.271	Val Cost: 0.313
# Epoch 200, Train Cost: 0.186	Val Cost: 0.168
# Epoch 300, Train Cost: 0.018	Val Cost: 0.162
# Epoch 400, Train Cost: 0.006	Val Cost: 0.175
# Epoch 500, Train Cost: 0.002	Val Cost: 0.201
# Epoch 600, Train Cost: 0.001	Val Cost: 0.214
# Epoch 700, Train Cost: 0.001	Val Cost: 0.224
# Epoch 800, Train Cost: 0.001	Val Cost: 0.231
# Epoch 900, Train Cost: 0.000	Val Cost: 0.237
#
# Test Cost: 0.151
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.782	Val Cost: 0.629
# Epoch 100, Train Cost: 0.242	Val Cost: 0.263
# Epoch 200, Train Cost: 0.974	Val Cost: 0.531
# Epoch 300, Train Cost: 0.004	Val Cost: 0.179
# Epoch 400, Train Cost: 0.001	Val Cost: 0.203
# Epoch 500, Train Cost: 0.001	Val Cost: 0.217
# Epoch 600, Train Cost: 0.001	Val Cost: 0.226
# Epoch 700, Train Cost: 0.001	Val Cost: 0.233
# Epoch 800, Train Cost: 0.000	Val Cost: 0.238
# Epoch 900, Train Cost: 0.000	Val Cost: 0.243
#
# Test Cost: 0.150
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.744	Val Cost: 0.653
# Epoch 100, Train Cost: 0.423	Val Cost: 0.457
# Epoch 200, Train Cost: 0.117	Val Cost: 0.200
# Epoch 300, Train Cost: 0.173	Val Cost: 0.270
# Epoch 400, Train Cost: 0.172	Val Cost: 0.255
# Epoch 500, Train Cost: 0.006	Val Cost: 0.194
# Epoch 600, Train Cost: 0.001	Val Cost: 0.233
# Epoch 700, Train Cost: 0.001	Val Cost: 0.248
# Epoch 800, Train Cost: 0.001	Val Cost: 0.258
# Epoch 900, Train Cost: 0.000	Val Cost: 0.265
#
# Test Cost: 0.174
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.645	Val Cost: 0.583
# Epoch 100, Train Cost: 0.209	Val Cost: 0.245
# Epoch 200, Train Cost: 0.158	Val Cost: 0.399
# Epoch 300, Train Cost: 0.011	Val Cost: 0.160
# Epoch 400, Train Cost: 0.002	Val Cost: 0.192
# Epoch 500, Train Cost: 0.001	Val Cost: 0.207
# Epoch 600, Train Cost: 0.001	Val Cost: 0.218
# Epoch 700, Train Cost: 0.001	Val Cost: 0.225
# Epoch 800, Train Cost: 0.000	Val Cost: 0.231
# Epoch 900, Train Cost: 0.000	Val Cost: 0.236
#
# Test Cost: 0.153
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.500	Val Cost: 0.871
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.307	Val Cost: 0.333
# Epoch 400, Train Cost: 0.302	Val Cost: 0.333
# Epoch 500, Train Cost: 0.295	Val Cost: 0.332
# Epoch 600, Train Cost: 0.286	Val Cost: 0.331
# Epoch 700, Train Cost: 0.279	Val Cost: 0.329
# Epoch 800, Train Cost: 0.273	Val Cost: 0.329
# Epoch 900, Train Cost: 0.270	Val Cost: 0.329
#
# Test Cost: 0.293
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.635	Val Cost: 0.583
# Epoch 100, Train Cost: 0.314	Val Cost: 0.296
# Epoch 200, Train Cost: 0.053	Val Cost: 0.155
# Epoch 300, Train Cost: 0.016	Val Cost: 0.177
# Epoch 400, Train Cost: 0.004	Val Cost: 0.188
# Epoch 500, Train Cost: 0.002	Val Cost: 0.203
# Epoch 600, Train Cost: 0.002	Val Cost: 0.214
# Epoch 700, Train Cost: 0.001	Val Cost: 0.222
# Epoch 800, Train Cost: 0.001	Val Cost: 0.229
# Epoch 900, Train Cost: 0.001	Val Cost: 0.234
#
# Test Cost: 0.065
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.693	Val Cost: 0.651
# Epoch 100, Train Cost: 0.131	Val Cost: 0.174
# Epoch 200, Train Cost: 0.029	Val Cost: 0.197
# Epoch 300, Train Cost: 0.002	Val Cost: 0.189
# Epoch 400, Train Cost: 0.001	Val Cost: 0.202
# Epoch 500, Train Cost: 0.001	Val Cost: 0.211
# Epoch 600, Train Cost: 0.001	Val Cost: 0.218
# Epoch 700, Train Cost: 0.000	Val Cost: 0.223
# Epoch 800, Train Cost: 0.000	Val Cost: 0.228
# Epoch 900, Train Cost: 0.000	Val Cost: 0.232
#
# Test Cost: 0.144
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.773	Val Cost: 0.683
# Epoch 100, Train Cost: 0.296	Val Cost: 0.321
# Epoch 200, Train Cost: 0.207	Val Cost: 0.292
# Epoch 300, Train Cost: 0.051	Val Cost: 0.167
# Epoch 400, Train Cost: 0.004	Val Cost: 0.180
# Epoch 500, Train Cost: 0.002	Val Cost: 0.199
# Epoch 600, Train Cost: 0.001	Val Cost: 0.211
# Epoch 700, Train Cost: 0.001	Val Cost: 0.220
# Epoch 800, Train Cost: 0.001	Val Cost: 0.227
# Epoch 900, Train Cost: 0.001	Val Cost: 0.233
#
# Test Cost: 0.260
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.628	Val Cost: 0.542
# Epoch 100, Train Cost: 0.196	Val Cost: 0.224
# Epoch 200, Train Cost: 0.079	Val Cost: 0.150
# Epoch 300, Train Cost: 0.006	Val Cost: 0.173
# Epoch 400, Train Cost: 0.026	Val Cost: 0.193
# Epoch 500, Train Cost: 0.002	Val Cost: 0.194
# Epoch 600, Train Cost: 0.001	Val Cost: 0.210
# Epoch 700, Train Cost: 0.001	Val Cost: 0.220
# Epoch 800, Train Cost: 0.001	Val Cost: 0.228
# Epoch 900, Train Cost: 0.000	Val Cost: 0.234
#
# Test Cost: 0.163
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.942	Val Cost: 0.680
# Epoch 100, Train Cost: 0.318	Val Cost: 0.267
# Epoch 200, Train Cost: 0.089	Val Cost: 0.185
# Epoch 300, Train Cost: 0.002	Val Cost: 0.184
# Epoch 400, Train Cost: 0.001	Val Cost: 0.203
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.223
# Epoch 700, Train Cost: 0.000	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.235
# Epoch 900, Train Cost: 0.000	Val Cost: 0.239
#
# Test Cost: 0.153
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.618	Val Cost: 0.483
# Epoch 100, Train Cost: 0.202	Val Cost: 0.702
# Epoch 200, Train Cost: 0.407	Val Cost: 0.437
# Epoch 300, Train Cost: 0.070	Val Cost: 0.162
# Epoch 400, Train Cost: 0.150	Val Cost: 0.204
# Epoch 500, Train Cost: 0.051	Val Cost: 0.189
# Epoch 600, Train Cost: 0.051	Val Cost: 0.196
# Epoch 700, Train Cost: 0.050	Val Cost: 0.198
# Epoch 800, Train Cost: 0.347	Val Cost: 0.381
# Epoch 900, Train Cost: 0.346	Val Cost: 0.380
#
# Test Cost: 0.395
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.757	Val Cost: 0.702
# Epoch 100, Train Cost: 0.312	Val Cost: 0.335
# Epoch 200, Train Cost: 0.246	Val Cost: 0.285
# Epoch 300, Train Cost: 0.171	Val Cost: 0.247
# Epoch 400, Train Cost: 0.142	Val Cost: 0.249
# Epoch 500, Train Cost: 0.126	Val Cost: 0.258
# Epoch 600, Train Cost: 0.115	Val Cost: 0.268
# Epoch 700, Train Cost: 0.107	Val Cost: 0.279
# Epoch 800, Train Cost: 0.101	Val Cost: 0.291
# Epoch 900, Train Cost: 0.096	Val Cost: 0.304
#
# Test Cost: 0.094
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.799	Val Cost: 0.728
# Epoch 100, Train Cost: 0.216	Val Cost: 0.241
# Epoch 200, Train Cost: 0.024	Val Cost: 0.159
# Epoch 300, Train Cost: 0.010	Val Cost: 0.164
# Epoch 400, Train Cost: 0.003	Val Cost: 0.179
# Epoch 500, Train Cost: 0.002	Val Cost: 0.191
# Epoch 600, Train Cost: 0.002	Val Cost: 0.200
# Epoch 700, Train Cost: 0.001	Val Cost: 0.207
# Epoch 800, Train Cost: 0.001	Val Cost: 0.213
# Epoch 900, Train Cost: 0.001	Val Cost: 0.218
#
# Test Cost: 0.070
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.560	Val Cost: 0.400
# Epoch 100, Train Cost: 0.226	Val Cost: 0.290
# Epoch 200, Train Cost: 0.185	Val Cost: 0.301
# Epoch 300, Train Cost: 0.154	Val Cost: 0.272
# Epoch 400, Train Cost: 0.143	Val Cost: 0.246
# Epoch 500, Train Cost: 0.123	Val Cost: 0.249
# Epoch 600, Train Cost: 0.011	Val Cost: 0.201
# Epoch 700, Train Cost: 0.003	Val Cost: 0.228
# Epoch 800, Train Cost: 0.002	Val Cost: 0.242
# Epoch 900, Train Cost: 0.001	Val Cost: 0.252
#
# Test Cost: 0.144
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.641	Val Cost: 0.596
# Epoch 100, Train Cost: 0.320	Val Cost: 0.338
# Epoch 200, Train Cost: 0.152	Val Cost: 1.033
# Epoch 300, Train Cost: 0.022	Val Cost: 0.162
# Epoch 400, Train Cost: 0.296	Val Cost: 0.377
# Epoch 500, Train Cost: 0.004	Val Cost: 0.176
# Epoch 600, Train Cost: 0.002	Val Cost: 0.201
# Epoch 700, Train Cost: 0.001	Val Cost: 0.215
# Epoch 800, Train Cost: 0.001	Val Cost: 0.224
# Epoch 900, Train Cost: 0.001	Val Cost: 0.231
#
# Test Cost: 0.097
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.778	Val Cost: 0.716
# Epoch 100, Train Cost: 0.296	Val Cost: 0.362
# Epoch 200, Train Cost: 0.042	Val Cost: 0.181
# Epoch 300, Train Cost: 0.038	Val Cost: 0.161
# Epoch 400, Train Cost: 0.011	Val Cost: 0.161
# Epoch 500, Train Cost: 0.002	Val Cost: 0.194
# Epoch 600, Train Cost: 0.001	Val Cost: 0.209
# Epoch 700, Train Cost: 0.001	Val Cost: 0.219
# Epoch 800, Train Cost: 0.001	Val Cost: 0.227
# Epoch 900, Train Cost: 0.000	Val Cost: 0.233
#
# Test Cost: 0.129
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.653	Val Cost: 0.547
# Epoch 100, Train Cost: 0.273	Val Cost: 0.287
# Epoch 200, Train Cost: 0.233	Val Cost: 0.210
# Epoch 300, Train Cost: 0.003	Val Cost: 0.220
# Epoch 400, Train Cost: 0.001	Val Cost: 0.248
# Epoch 500, Train Cost: 0.001	Val Cost: 0.265
# Epoch 600, Train Cost: 0.001	Val Cost: 0.276
# Epoch 700, Train Cost: 0.001	Val Cost: 0.285
# Epoch 800, Train Cost: 0.000	Val Cost: 0.293
# Epoch 900, Train Cost: 0.000	Val Cost: 0.299
#
# Test Cost: 0.168
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.648	Val Cost: 0.586
# Epoch 100, Train Cost: 0.304	Val Cost: 0.373
# Epoch 200, Train Cost: 0.141	Val Cost: 0.258
# Epoch 300, Train Cost: 0.005	Val Cost: 0.221
# Epoch 400, Train Cost: 0.001	Val Cost: 0.250
# Epoch 500, Train Cost: 0.001	Val Cost: 0.262
# Epoch 600, Train Cost: 0.001	Val Cost: 0.270
# Epoch 700, Train Cost: 0.000	Val Cost: 0.276
# Epoch 800, Train Cost: 0.000	Val Cost: 0.281
# Epoch 900, Train Cost: 0.000	Val Cost: 0.285
#
# Test Cost: 0.135
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.819	Val Cost: 0.563
# Epoch 100, Train Cost: 0.306	Val Cost: 0.329
# Epoch 200, Train Cost: 0.205	Val Cost: 0.234
# Epoch 300, Train Cost: 0.164	Val Cost: 0.214
# Epoch 400, Train Cost: 0.144	Val Cost: 0.217
# Epoch 500, Train Cost: 0.132	Val Cost: 0.225
# Epoch 600, Train Cost: 0.124	Val Cost: 0.235
# Epoch 700, Train Cost: 0.117	Val Cost: 0.247
# Epoch 800, Train Cost: 0.112	Val Cost: 0.259
# Epoch 900, Train Cost: 0.108	Val Cost: 0.271
#
# Test Cost: 0.127
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.790	Val Cost: 0.666
# Epoch 100, Train Cost: 0.311	Val Cost: 0.319
# Epoch 200, Train Cost: 0.086	Val Cost: 0.139
# Epoch 300, Train Cost: 0.019	Val Cost: 0.158
# Epoch 400, Train Cost: 0.004	Val Cost: 0.168
# Epoch 500, Train Cost: 0.003	Val Cost: 0.180
# Epoch 600, Train Cost: 0.002	Val Cost: 0.189
# Epoch 700, Train Cost: 0.002	Val Cost: 0.196
# Epoch 800, Train Cost: 0.001	Val Cost: 0.201
# Epoch 900, Train Cost: 0.001	Val Cost: 0.206
#
# Test Cost: 0.080
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.827	Val Cost: 0.668
# Epoch 100, Train Cost: 0.271	Val Cost: 0.335
# Epoch 200, Train Cost: 0.116	Val Cost: 0.221
# Epoch 300, Train Cost: 0.005	Val Cost: 0.174
# Epoch 400, Train Cost: 0.002	Val Cost: 0.201
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.001	Val Cost: 0.231
# Epoch 800, Train Cost: 0.000	Val Cost: 0.237
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.081
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.588	Val Cost: 0.582
# Epoch 100, Train Cost: 0.934	Val Cost: 0.581
# Epoch 200, Train Cost: 0.015	Val Cost: 0.201
# Epoch 300, Train Cost: 0.003	Val Cost: 0.187
# Epoch 400, Train Cost: 0.001	Val Cost: 0.206
# Epoch 500, Train Cost: 0.001	Val Cost: 0.217
# Epoch 600, Train Cost: 0.001	Val Cost: 0.225
# Epoch 700, Train Cost: 0.000	Val Cost: 0.231
# Epoch 800, Train Cost: 0.000	Val Cost: 0.236
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.138
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.747	Val Cost: 0.676
# Epoch 100, Train Cost: 0.134	Val Cost: 0.305
# Epoch 200, Train Cost: 0.035	Val Cost: 0.206
# Epoch 300, Train Cost: 0.026	Val Cost: 0.171
# Epoch 400, Train Cost: 0.003	Val Cost: 0.178
# Epoch 500, Train Cost: 0.001	Val Cost: 0.201
# Epoch 600, Train Cost: 0.001	Val Cost: 0.214
# Epoch 700, Train Cost: 0.001	Val Cost: 0.223
# Epoch 800, Train Cost: 0.001	Val Cost: 0.229
# Epoch 900, Train Cost: 0.000	Val Cost: 0.235
#
# Test Cost: 0.119
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.651	Val Cost: 0.546
# Epoch 100, Train Cost: 0.260	Val Cost: 0.250
# Epoch 200, Train Cost: 0.059	Val Cost: 0.155
# Epoch 300, Train Cost: 0.007	Val Cost: 0.192
# Epoch 400, Train Cost: 0.002	Val Cost: 0.217
# Epoch 500, Train Cost: 0.001	Val Cost: 0.226
# Epoch 600, Train Cost: 0.001	Val Cost: 0.233
# Epoch 700, Train Cost: 0.001	Val Cost: 0.238
# Epoch 800, Train Cost: 0.000	Val Cost: 0.242
# Epoch 900, Train Cost: 0.000	Val Cost: 0.246
#
# Test Cost: 0.152
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.733	Val Cost: 0.658
# Epoch 100, Train Cost: 0.406	Val Cost: 0.415
# Epoch 200, Train Cost: 0.260	Val Cost: 0.337
# Epoch 300, Train Cost: 0.022	Val Cost: 0.164
# Epoch 400, Train Cost: 0.323	Val Cost: 0.348
# Epoch 500, Train Cost: 0.172	Val Cost: 0.256
# Epoch 600, Train Cost: 0.172	Val Cost: 0.258
# Epoch 700, Train Cost: 0.172	Val Cost: 0.260
# Epoch 800, Train Cost: 0.172	Val Cost: 0.261
# Epoch 900, Train Cost: 0.102	Val Cost: 0.209
#
# Test Cost: 0.100
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.729	Val Cost: 0.583
# Epoch 100, Train Cost: 0.266	Val Cost: 0.291
# Epoch 200, Train Cost: 0.184	Val Cost: 0.240
# Epoch 300, Train Cost: 0.146	Val Cost: 0.247
# Epoch 400, Train Cost: 0.128	Val Cost: 0.255
# Epoch 500, Train Cost: 0.116	Val Cost: 0.266
# Epoch 600, Train Cost: 0.108	Val Cost: 0.277
# Epoch 700, Train Cost: 0.101	Val Cost: 0.288
# Epoch 800, Train Cost: 0.096	Val Cost: 0.301
# Epoch 900, Train Cost: 0.092	Val Cost: 0.314
#
# Test Cost: 0.093
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.708	Val Cost: 0.635
# Epoch 100, Train Cost: 0.276	Val Cost: 0.335
# Epoch 200, Train Cost: 0.068	Val Cost: 0.188
# Epoch 300, Train Cost: 0.008	Val Cost: 0.177
# Epoch 400, Train Cost: 0.004	Val Cost: 0.194
# Epoch 500, Train Cost: 0.003	Val Cost: 0.205
# Epoch 600, Train Cost: 0.002	Val Cost: 0.213
# Epoch 700, Train Cost: 0.002	Val Cost: 0.220
# Epoch 800, Train Cost: 0.001	Val Cost: 0.225
# Epoch 900, Train Cost: 0.001	Val Cost: 0.229
#
# Test Cost: 0.065
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.807	Val Cost: 0.569
# Epoch 100, Train Cost: 0.296	Val Cost: 0.244
# Epoch 200, Train Cost: 0.160	Val Cost: 0.208
# Epoch 300, Train Cost: 0.086	Val Cost: 0.190
# Epoch 400, Train Cost: 0.002	Val Cost: 0.198
# Epoch 500, Train Cost: 0.001	Val Cost: 0.212
# Epoch 600, Train Cost: 0.001	Val Cost: 0.220
# Epoch 700, Train Cost: 0.001	Val Cost: 0.227
# Epoch 800, Train Cost: 0.001	Val Cost: 0.232
# Epoch 900, Train Cost: 0.000	Val Cost: 0.237
#
# Test Cost: 0.139
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.928	Val Cost: 0.579
# Epoch 100, Train Cost: 0.205	Val Cost: 0.421
# Epoch 200, Train Cost: 0.016	Val Cost: 0.159
# Epoch 300, Train Cost: 0.002	Val Cost: 0.188
# Epoch 400, Train Cost: 0.001	Val Cost: 0.207
# Epoch 500, Train Cost: 0.001	Val Cost: 0.218
# Epoch 600, Train Cost: 0.001	Val Cost: 0.226
# Epoch 700, Train Cost: 0.000	Val Cost: 0.233
# Epoch 800, Train Cost: 0.000	Val Cost: 0.238
# Epoch 900, Train Cost: 0.000	Val Cost: 0.242
#
# Test Cost: 0.131
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.717	Val Cost: 0.595
# Epoch 100, Train Cost: 0.173	Val Cost: 0.471
# Epoch 200, Train Cost: 0.392	Val Cost: 0.399
# Epoch 300, Train Cost: 0.135	Val Cost: 0.201
# Epoch 400, Train Cost: 0.017	Val Cost: 0.173
# Epoch 500, Train Cost: 0.002	Val Cost: 0.193
# Epoch 600, Train Cost: 0.001	Val Cost: 0.209
# Epoch 700, Train Cost: 0.001	Val Cost: 0.219
# Epoch 800, Train Cost: 0.001	Val Cost: 0.226
# Epoch 900, Train Cost: 0.000	Val Cost: 0.232
#
# Test Cost: 0.127
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.673	Val Cost: 0.567
# Epoch 100, Train Cost: 0.835	Val Cost: 0.507
# Epoch 200, Train Cost: 0.160	Val Cost: 0.151
# Epoch 300, Train Cost: 0.014	Val Cost: 0.175
# Epoch 400, Train Cost: 0.003	Val Cost: 0.184
# Epoch 500, Train Cost: 0.001	Val Cost: 0.203
# Epoch 600, Train Cost: 0.001	Val Cost: 0.215
# Epoch 700, Train Cost: 0.001	Val Cost: 0.223
# Epoch 800, Train Cost: 0.000	Val Cost: 0.230
# Epoch 900, Train Cost: 0.000	Val Cost: 0.235
#
# Test Cost: 0.149
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.717	Val Cost: 0.839
# Epoch 100, Train Cost: 0.204	Val Cost: 0.279
# Epoch 200, Train Cost: 0.063	Val Cost: 0.197
# Epoch 300, Train Cost: 0.003	Val Cost: 0.179
# Epoch 400, Train Cost: 0.001	Val Cost: 0.201
# Epoch 500, Train Cost: 0.001	Val Cost: 0.213
# Epoch 600, Train Cost: 0.001	Val Cost: 0.222
# Epoch 700, Train Cost: 0.001	Val Cost: 0.229
# Epoch 800, Train Cost: 0.000	Val Cost: 0.234
# Epoch 900, Train Cost: 0.000	Val Cost: 0.239
#
# Test Cost: 0.099
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.713	Val Cost: 0.602
# Epoch 100, Train Cost: 0.271	Val Cost: 0.298
# Epoch 200, Train Cost: 0.238	Val Cost: 0.351
# Epoch 300, Train Cost: 0.143	Val Cost: 0.252
# Epoch 400, Train Cost: 0.127	Val Cost: 0.258
# Epoch 500, Train Cost: 0.116	Val Cost: 0.268
# Epoch 600, Train Cost: 0.108	Val Cost: 0.279
# Epoch 700, Train Cost: 0.101	Val Cost: 0.290
# Epoch 800, Train Cost: 0.096	Val Cost: 0.303
# Epoch 900, Train Cost: 0.092	Val Cost: 0.316
#
# Test Cost: 0.093
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.617	Val Cost: 0.538
# Epoch 100, Train Cost: 0.168	Val Cost: 0.303
# Epoch 200, Train Cost: 0.020	Val Cost: 0.173
# Epoch 300, Train Cost: 0.012	Val Cost: 0.191
# Epoch 400, Train Cost: 0.003	Val Cost: 0.202
# Epoch 500, Train Cost: 0.002	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.225
# Epoch 700, Train Cost: 0.001	Val Cost: 0.233
# Epoch 800, Train Cost: 0.001	Val Cost: 0.239
# Epoch 900, Train Cost: 0.001	Val Cost: 0.244
#
# Test Cost: 0.065
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.726	Val Cost: 0.692
# Epoch 100, Train Cost: 0.247	Val Cost: 0.311
# Epoch 200, Train Cost: 0.202	Val Cost: 0.304
# Epoch 300, Train Cost: 0.041	Val Cost: 0.190
# Epoch 400, Train Cost: 0.005	Val Cost: 0.154
# Epoch 500, Train Cost: 0.003	Val Cost: 0.168
# Epoch 600, Train Cost: 0.002	Val Cost: 0.178
# Epoch 700, Train Cost: 0.001	Val Cost: 0.185
# Epoch 800, Train Cost: 0.001	Val Cost: 0.191
# Epoch 900, Train Cost: 0.001	Val Cost: 0.196
#
# Test Cost: 0.065
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.745	Val Cost: 0.661
# Epoch 100, Train Cost: 0.292	Val Cost: 0.343
# Epoch 200, Train Cost: 0.158	Val Cost: 0.196
# Epoch 300, Train Cost: 0.005	Val Cost: 0.148
# Epoch 400, Train Cost: 0.001	Val Cost: 0.175
# Epoch 500, Train Cost: 0.001	Val Cost: 0.190
# Epoch 600, Train Cost: 0.001	Val Cost: 0.200
# Epoch 700, Train Cost: 0.001	Val Cost: 0.208
# Epoch 800, Train Cost: 0.000	Val Cost: 0.215
# Epoch 900, Train Cost: 0.000	Val Cost: 0.221
#
# Test Cost: 0.148
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.524	Val Cost: 0.572
# Epoch 100, Train Cost: 0.457	Val Cost: 0.450
# Epoch 200, Train Cost: 0.308	Val Cost: 0.234
# Epoch 300, Train Cost: 0.002	Val Cost: 0.187
# Epoch 400, Train Cost: 0.001	Val Cost: 0.204
# Epoch 500, Train Cost: 0.001	Val Cost: 0.216
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.000	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.235
# Epoch 900, Train Cost: 0.000	Val Cost: 0.240
#
# Test Cost: 0.138
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.688	Val Cost: 0.599
# Epoch 100, Train Cost: 0.529	Val Cost: 0.504
# Epoch 200, Train Cost: 0.121	Val Cost: 0.172
# Epoch 300, Train Cost: 0.002	Val Cost: 0.184
# Epoch 400, Train Cost: 0.001	Val Cost: 0.202
# Epoch 500, Train Cost: 0.001	Val Cost: 0.213
# Epoch 600, Train Cost: 0.001	Val Cost: 0.221
# Epoch 700, Train Cost: 0.000	Val Cost: 0.228
# Epoch 800, Train Cost: 0.000	Val Cost: 0.233
# Epoch 900, Train Cost: 0.000	Val Cost: 0.237
#
# Test Cost: 0.249
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.101	Val Cost: 0.591
# Epoch 100, Train Cost: 0.199	Val Cost: 0.259
# Epoch 200, Train Cost: 0.079	Val Cost: 0.164
# Epoch 300, Train Cost: 0.033	Val Cost: 0.169
# Epoch 400, Train Cost: 0.002	Val Cost: 0.207
# Epoch 500, Train Cost: 0.001	Val Cost: 0.224
# Epoch 600, Train Cost: 0.001	Val Cost: 0.235
# Epoch 700, Train Cost: 0.001	Val Cost: 0.243
# Epoch 800, Train Cost: 0.000	Val Cost: 0.250
# Epoch 900, Train Cost: 0.000	Val Cost: 0.255
#
# Test Cost: 0.122
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.118	Val Cost: 0.787
# Epoch 100, Train Cost: 0.312	Val Cost: 0.337
# Epoch 200, Train Cost: 0.342	Val Cost: 0.346
# Epoch 300, Train Cost: 0.312	Val Cost: 0.332
# Epoch 400, Train Cost: 0.305	Val Cost: 0.333
# Epoch 500, Train Cost: 0.299	Val Cost: 0.333
# Epoch 600, Train Cost: 0.292	Val Cost: 0.333
# Epoch 700, Train Cost: 0.284	Val Cost: 0.332
# Epoch 800, Train Cost: 0.277	Val Cost: 0.329
# Epoch 900, Train Cost: 0.272	Val Cost: 0.328
#
# Test Cost: 0.288
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.271	Val Cost: 0.826
# Epoch 100, Train Cost: 0.291	Val Cost: 0.321
# Epoch 200, Train Cost: 0.236	Val Cost: 0.286
# Epoch 300, Train Cost: 0.204	Val Cost: 0.275
# Epoch 400, Train Cost: 0.183	Val Cost: 0.271
# Epoch 500, Train Cost: 0.149	Val Cost: 0.263
# Epoch 600, Train Cost: 0.140	Val Cost: 0.274
# Epoch 700, Train Cost: 0.134	Val Cost: 0.274
# Epoch 800, Train Cost: 0.112	Val Cost: 0.303
# Epoch 900, Train Cost: 0.092	Val Cost: 0.225
#
# Test Cost: 0.104
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.843	Val Cost: 0.684
# Epoch 100, Train Cost: 0.306	Val Cost: 0.359
# Epoch 200, Train Cost: 0.218	Val Cost: 0.414
# Epoch 300, Train Cost: 0.007	Val Cost: 0.162
# Epoch 400, Train Cost: 0.003	Val Cost: 0.185
# Epoch 500, Train Cost: 0.002	Val Cost: 0.198
# Epoch 600, Train Cost: 0.001	Val Cost: 0.208
# Epoch 700, Train Cost: 0.001	Val Cost: 0.215
# Epoch 800, Train Cost: 0.001	Val Cost: 0.221
# Epoch 900, Train Cost: 0.001	Val Cost: 0.226
#
# Test Cost: 0.094
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.679	Val Cost: 0.664
# Epoch 100, Train Cost: 0.197	Val Cost: 0.220
# Epoch 200, Train Cost: 0.115	Val Cost: 0.164
# Epoch 300, Train Cost: 0.270	Val Cost: 0.842
# Epoch 400, Train Cost: 0.041	Val Cost: 0.162
# Epoch 500, Train Cost: 0.003	Val Cost: 0.183
# Epoch 600, Train Cost: 0.001	Val Cost: 0.204
# Epoch 700, Train Cost: 0.001	Val Cost: 0.216
# Epoch 800, Train Cost: 0.001	Val Cost: 0.225
# Epoch 900, Train Cost: 0.001	Val Cost: 0.231
#
# Test Cost: 0.120
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.711	Val Cost: 0.655
# Epoch 100, Train Cost: 0.377	Val Cost: 0.313
# Epoch 200, Train Cost: 0.046	Val Cost: 0.171
# Epoch 300, Train Cost: 0.003	Val Cost: 0.189
# Epoch 400, Train Cost: 0.001	Val Cost: 0.204
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.223
# Epoch 700, Train Cost: 0.000	Val Cost: 0.229
# Epoch 800, Train Cost: 0.000	Val Cost: 0.234
# Epoch 900, Train Cost: 0.000	Val Cost: 0.239
#
# Test Cost: 0.154
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.650	Val Cost: 0.483
# Epoch 100, Train Cost: 0.343	Val Cost: 0.361
# Epoch 200, Train Cost: 0.159	Val Cost: 0.209
# Epoch 300, Train Cost: 0.016	Val Cost: 0.169
# Epoch 400, Train Cost: 0.003	Val Cost: 0.185
# Epoch 500, Train Cost: 0.001	Val Cost: 0.203
# Epoch 600, Train Cost: 0.001	Val Cost: 0.215
# Epoch 700, Train Cost: 0.001	Val Cost: 0.223
# Epoch 800, Train Cost: 0.000	Val Cost: 0.230
# Epoch 900, Train Cost: 0.000	Val Cost: 0.235
#
# Test Cost: 0.131
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.672	Val Cost: 0.616
# Epoch 100, Train Cost: 0.355	Val Cost: 0.342
# Epoch 200, Train Cost: 0.237	Val Cost: 0.217
# Epoch 300, Train Cost: 0.067	Val Cost: 0.165
# Epoch 400, Train Cost: 0.041	Val Cost: 0.402
# Epoch 500, Train Cost: 0.005	Val Cost: 0.205
# Epoch 600, Train Cost: 0.002	Val Cost: 0.235
# Epoch 700, Train Cost: 0.002	Val Cost: 0.253
# Epoch 800, Train Cost: 0.001	Val Cost: 0.266
# Epoch 900, Train Cost: 0.001	Val Cost: 0.278
#
# Test Cost: 0.163
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.661	Val Cost: 0.582
# Epoch 100, Train Cost: 0.306	Val Cost: 0.328
# Epoch 200, Train Cost: 0.236	Val Cost: 0.289
# Epoch 300, Train Cost: 0.164	Val Cost: 0.215
# Epoch 400, Train Cost: 0.144	Val Cost: 0.217
# Epoch 500, Train Cost: 0.132	Val Cost: 0.225
# Epoch 600, Train Cost: 0.124	Val Cost: 0.236
# Epoch 700, Train Cost: 0.117	Val Cost: 0.247
# Epoch 800, Train Cost: 0.112	Val Cost: 0.259
# Epoch 900, Train Cost: 0.108	Val Cost: 0.272
#
# Test Cost: 0.127
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.847	Val Cost: 0.446
# Epoch 100, Train Cost: 0.164	Val Cost: 0.254
# Epoch 200, Train Cost: 0.021	Val Cost: 0.135
# Epoch 300, Train Cost: 0.006	Val Cost: 0.159
# Epoch 400, Train Cost: 0.003	Val Cost: 0.174
# Epoch 500, Train Cost: 0.002	Val Cost: 0.185
# Epoch 600, Train Cost: 0.002	Val Cost: 0.193
# Epoch 700, Train Cost: 0.001	Val Cost: 0.199
# Epoch 800, Train Cost: 0.001	Val Cost: 0.204
# Epoch 900, Train Cost: 0.001	Val Cost: 0.209
#
# Test Cost: 0.078
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.443	Val Cost: 0.411
# Epoch 100, Train Cost: 0.209	Val Cost: 0.308
# Epoch 200, Train Cost: 0.108	Val Cost: 0.245
# Epoch 300, Train Cost: 0.002	Val Cost: 0.204
# Epoch 400, Train Cost: 0.001	Val Cost: 0.218
# Epoch 500, Train Cost: 0.001	Val Cost: 0.226
# Epoch 600, Train Cost: 0.001	Val Cost: 0.233
# Epoch 700, Train Cost: 0.000	Val Cost: 0.238
# Epoch 800, Train Cost: 0.000	Val Cost: 0.242
# Epoch 900, Train Cost: 0.000	Val Cost: 0.246
#
# Test Cost: 0.101
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.814	Val Cost: 0.607
# Epoch 100, Train Cost: 0.200	Val Cost: 0.246
# Epoch 200, Train Cost: 0.016	Val Cost: 0.178
# Epoch 300, Train Cost: 0.002	Val Cost: 0.194
# Epoch 400, Train Cost: 0.001	Val Cost: 0.209
# Epoch 500, Train Cost: 0.001	Val Cost: 0.219
# Epoch 600, Train Cost: 0.001	Val Cost: 0.226
# Epoch 700, Train Cost: 0.000	Val Cost: 0.232
# Epoch 800, Train Cost: 0.000	Val Cost: 0.237
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.130
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.729	Val Cost: 0.698
# Epoch 100, Train Cost: 0.476	Val Cost: 0.485
# Epoch 200, Train Cost: 0.046	Val Cost: 0.173
# Epoch 300, Train Cost: 0.004	Val Cost: 0.175
# Epoch 400, Train Cost: 0.001	Val Cost: 0.198
# Epoch 500, Train Cost: 0.001	Val Cost: 0.211
# Epoch 600, Train Cost: 0.001	Val Cost: 0.221
# Epoch 700, Train Cost: 0.001	Val Cost: 0.228
# Epoch 800, Train Cost: 0.000	Val Cost: 0.233
# Epoch 900, Train Cost: 0.000	Val Cost: 0.238
#
# Test Cost: 0.141
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.919	Val Cost: 0.419
# Epoch 100, Train Cost: 0.315	Val Cost: 0.268
# Epoch 200, Train Cost: 0.351	Val Cost: 0.239
# Epoch 300, Train Cost: 0.008	Val Cost: 0.160
# Epoch 400, Train Cost: 0.002	Val Cost: 0.200
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.225
# Epoch 700, Train Cost: 0.001	Val Cost: 0.232
# Epoch 800, Train Cost: 0.000	Val Cost: 0.237
# Epoch 900, Train Cost: 0.000	Val Cost: 0.242
#
# Test Cost: 0.150
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.610	Val Cost: 0.508
# Epoch 100, Train Cost: 0.246	Val Cost: 0.355
# Epoch 200, Train Cost: 0.049	Val Cost: 0.183
# Epoch 300, Train Cost: 0.003	Val Cost: 0.223
# Epoch 400, Train Cost: 0.001	Val Cost: 0.242
# Epoch 500, Train Cost: 0.001	Val Cost: 0.252
# Epoch 600, Train Cost: 0.001	Val Cost: 0.259
# Epoch 700, Train Cost: 0.001	Val Cost: 0.264
# Epoch 800, Train Cost: 0.000	Val Cost: 0.268
# Epoch 900, Train Cost: 0.000	Val Cost: 0.271
#
# Test Cost: 0.212
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.570	Val Cost: 0.490
# Epoch 100, Train Cost: 0.305	Val Cost: 0.328
# Epoch 200, Train Cost: 0.205	Val Cost: 0.233
# Epoch 300, Train Cost: 0.165	Val Cost: 0.214
# Epoch 400, Train Cost: 0.145	Val Cost: 0.216
# Epoch 500, Train Cost: 0.132	Val Cost: 0.225
# Epoch 600, Train Cost: 0.124	Val Cost: 0.235
# Epoch 700, Train Cost: 0.117	Val Cost: 0.246
# Epoch 800, Train Cost: 0.112	Val Cost: 0.258
# Epoch 900, Train Cost: 0.108	Val Cost: 0.271
#
# Test Cost: 0.127
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.562	Val Cost: 0.452
# Epoch 100, Train Cost: 0.244	Val Cost: 0.324
# Epoch 200, Train Cost: 0.018	Val Cost: 0.151
# Epoch 300, Train Cost: 0.005	Val Cost: 0.174
# Epoch 400, Train Cost: 0.003	Val Cost: 0.193
# Epoch 500, Train Cost: 0.002	Val Cost: 0.205
# Epoch 600, Train Cost: 0.001	Val Cost: 0.215
# Epoch 700, Train Cost: 0.001	Val Cost: 0.223
# Epoch 800, Train Cost: 0.001	Val Cost: 0.229
# Epoch 900, Train Cost: 0.001	Val Cost: 0.235
#
# Test Cost: 0.066
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.732	Val Cost: 0.642
# Epoch 100, Train Cost: 0.129	Val Cost: 0.182
# Epoch 200, Train Cost: 0.060	Val Cost: 0.151
# Epoch 300, Train Cost: 0.009	Val Cost: 0.195
# Epoch 400, Train Cost: 0.002	Val Cost: 0.190
# Epoch 500, Train Cost: 0.001	Val Cost: 0.203
# Epoch 600, Train Cost: 0.001	Val Cost: 0.213
# Epoch 700, Train Cost: 0.001	Val Cost: 0.221
# Epoch 800, Train Cost: 0.001	Val Cost: 0.227
# Epoch 900, Train Cost: 0.000	Val Cost: 0.232
#
# Test Cost: 0.110
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 1.106	Val Cost: 0.805
# Epoch 100, Train Cost: 0.332	Val Cost: 0.363
# Epoch 200, Train Cost: 0.042	Val Cost: 0.157
# Epoch 300, Train Cost: 0.004	Val Cost: 0.174
# Epoch 400, Train Cost: 0.002	Val Cost: 0.201
# Epoch 500, Train Cost: 0.001	Val Cost: 0.214
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.001	Val Cost: 0.231
# Epoch 800, Train Cost: 0.000	Val Cost: 0.236
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.071
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.691	Val Cost: 0.693
# Epoch 100, Train Cost: 0.345	Val Cost: 0.412
# Epoch 200, Train Cost: 0.060	Val Cost: 0.197
# Epoch 300, Train Cost: 0.017	Val Cost: 0.178
# Epoch 400, Train Cost: 0.002	Val Cost: 0.207
# Epoch 500, Train Cost: 0.001	Val Cost: 0.220
# Epoch 600, Train Cost: 0.001	Val Cost: 0.228
# Epoch 700, Train Cost: 0.001	Val Cost: 0.234
# Epoch 800, Train Cost: 0.000	Val Cost: 0.239
# Epoch 900, Train Cost: 0.000	Val Cost: 0.243
#
# Test Cost: 0.154
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.681	Val Cost: 0.575
# Epoch 100, Train Cost: 0.403	Val Cost: 0.397
# Epoch 200, Train Cost: 0.296	Val Cost: 0.395
# Epoch 300, Train Cost: 0.276	Val Cost: 0.311
# Epoch 400, Train Cost: 0.009	Val Cost: 0.157
# Epoch 500, Train Cost: 0.002	Val Cost: 0.192
# Epoch 600, Train Cost: 0.001	Val Cost: 0.208
# Epoch 700, Train Cost: 0.001	Val Cost: 0.218
# Epoch 800, Train Cost: 0.001	Val Cost: 0.226
# Epoch 900, Train Cost: 0.000	Val Cost: 0.232
#
# Test Cost: 0.123
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.779	Val Cost: 0.685
# Epoch 100, Train Cost: 0.419	Val Cost: 0.449
# Epoch 200, Train Cost: 0.335	Val Cost: 0.343
# Epoch 300, Train Cost: 0.240	Val Cost: 0.255
# Epoch 400, Train Cost: 0.065	Val Cost: 0.179
# ...
# Epoch 700, Train Cost: 0.270	Val Cost: 0.330
# Epoch 800, Train Cost: 0.268	Val Cost: 0.331
# Epoch 900, Train Cost: 0.265	Val Cost: 0.332
#
# Test Cost: 0.304
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.559	Val Cost: 0.499
# Epoch 100, Train Cost: 0.273	Val Cost: 0.250
# Epoch 200, Train Cost: 0.023	Val Cost: 0.158
# Epoch 300, Train Cost: 0.014	Val Cost: 0.172
# Epoch 400, Train Cost: 0.003	Val Cost: 0.180
# Epoch 500, Train Cost: 0.002	Val Cost: 0.191
# Epoch 600, Train Cost: 0.002	Val Cost: 0.200
# Epoch 700, Train Cost: 0.001	Val Cost: 0.206
# Epoch 800, Train Cost: 0.001	Val Cost: 0.212
# Epoch 900, Train Cost: 0.001	Val Cost: 0.216
#
# Test Cost: 0.064
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.793	Val Cost: 0.643
# Epoch 100, Train Cost: 0.157	Val Cost: 0.293
# Epoch 200, Train Cost: 0.020	Val Cost: 0.211
# Epoch 300, Train Cost: 0.002	Val Cost: 0.190
# Epoch 400, Train Cost: 0.001	Val Cost: 0.205
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.222
# Epoch 700, Train Cost: 0.001	Val Cost: 0.228
# Epoch 800, Train Cost: 0.000	Val Cost: 0.233
# Epoch 900, Train Cost: 0.000	Val Cost: 0.237
#
# Test Cost: 0.118
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.856	Val Cost: 0.677
# Epoch 100, Train Cost: 0.239	Val Cost: 0.494
# Epoch 200, Train Cost: 0.059	Val Cost: 0.165
# Epoch 300, Train Cost: 0.060	Val Cost: 0.275
# Epoch 400, Train Cost: 0.003	Val Cost: 0.188
# Epoch 500, Train Cost: 0.001	Val Cost: 0.207
# Epoch 600, Train Cost: 0.001	Val Cost: 0.218
# Epoch 700, Train Cost: 0.001	Val Cost: 0.226
# Epoch 800, Train Cost: 0.000	Val Cost: 0.232
# Epoch 900, Train Cost: 0.000	Val Cost: 0.238
#
# Test Cost: 0.142
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.681	Val Cost: 0.667
# Epoch 100, Train Cost: 0.329	Val Cost: 0.329
# Epoch 200, Train Cost: 0.052	Val Cost: 0.321
# Epoch 300, Train Cost: 0.004	Val Cost: 0.172
# Epoch 400, Train Cost: 0.001	Val Cost: 0.195
# Epoch 500, Train Cost: 0.001	Val Cost: 0.208
# Epoch 600, Train Cost: 0.001	Val Cost: 0.218
# Epoch 700, Train Cost: 0.001	Val Cost: 0.225
# Epoch 800, Train Cost: 0.000	Val Cost: 0.231
# Epoch 900, Train Cost: 0.000	Val Cost: 0.236
#
# Test Cost: 0.154
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.625	Val Cost: 0.526
# Epoch 100, Train Cost: 0.272	Val Cost: 0.295
# Epoch 200, Train Cost: 0.036	Val Cost: 0.175
# Epoch 300, Train Cost: 0.004	Val Cost: 0.201
# Epoch 400, Train Cost: 0.002	Val Cost: 0.238
# Epoch 500, Train Cost: 0.001	Val Cost: 0.257
# Epoch 600, Train Cost: 0.001	Val Cost: 0.270
# Epoch 700, Train Cost: 0.001	Val Cost: 0.280
# Epoch 800, Train Cost: 0.000	Val Cost: 0.288
# Epoch 900, Train Cost: 0.000	Val Cost: 0.294
#
# Test Cost: 0.231
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.699	Val Cost: 0.686
# Epoch 100, Train Cost: 0.274	Val Cost: 0.321
# Epoch 200, Train Cost: 0.014	Val Cost: 0.153
# Epoch 300, Train Cost: 0.002	Val Cost: 0.187
# Epoch 400, Train Cost: 0.001	Val Cost: 0.205
# Epoch 500, Train Cost: 0.001	Val Cost: 0.216
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.000	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.235
# Epoch 900, Train Cost: 0.000	Val Cost: 0.240
#
# Test Cost: 0.084
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.621	Val Cost: 0.587
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.306	Val Cost: 0.334
# Epoch 300, Train Cost: 0.300	Val Cost: 0.332
# Epoch 400, Train Cost: 0.290	Val Cost: 0.329
# Epoch 500, Train Cost: 0.281	Val Cost: 0.328
# Epoch 600, Train Cost: 0.275	Val Cost: 0.329
# Epoch 700, Train Cost: 0.271	Val Cost: 0.329
# Epoch 800, Train Cost: 0.268	Val Cost: 0.330
# Epoch 900, Train Cost: 0.266	Val Cost: 0.331
#
# Test Cost: 0.303
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.773	Val Cost: 0.696
# Epoch 100, Train Cost: 0.306	Val Cost: 0.336
# Epoch 200, Train Cost: 0.274	Val Cost: 0.329
# Epoch 300, Train Cost: 0.227	Val Cost: 0.315
# Epoch 400, Train Cost: 0.185	Val Cost: 0.312
# Epoch 500, Train Cost: 0.015	Val Cost: 0.170
# Epoch 600, Train Cost: 0.005	Val Cost: 0.181
# Epoch 700, Train Cost: 0.003	Val Cost: 0.192
# Epoch 800, Train Cost: 0.002	Val Cost: 0.201
# Epoch 900, Train Cost: 0.002	Val Cost: 0.208
#
# Test Cost: 0.064
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.638	Val Cost: 0.556
# Epoch 100, Train Cost: 0.272	Val Cost: 0.300
# Epoch 200, Train Cost: 0.228	Val Cost: 0.277
# Epoch 300, Train Cost: 0.174	Val Cost: 0.269
# Epoch 400, Train Cost: 0.005	Val Cost: 0.199
# Epoch 500, Train Cost: 0.001	Val Cost: 0.225
# Epoch 600, Train Cost: 0.001	Val Cost: 0.233
# Epoch 700, Train Cost: 0.001	Val Cost: 0.239
# Epoch 800, Train Cost: 0.000	Val Cost: 0.243
# Epoch 900, Train Cost: 0.000	Val Cost: 0.247
#
# Test Cost: 0.098
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.709	Val Cost: 0.529
# Epoch 100, Train Cost: 0.300	Val Cost: 0.380
# Epoch 200, Train Cost: 0.264	Val Cost: 0.307
# Epoch 300, Train Cost: 0.202	Val Cost: 0.306
# Epoch 400, Train Cost: 0.047	Val Cost: 0.172
# Epoch 500, Train Cost: 0.003	Val Cost: 0.204
# Epoch 600, Train Cost: 0.001	Val Cost: 0.220
# Epoch 700, Train Cost: 0.001	Val Cost: 0.230
# Epoch 800, Train Cost: 0.001	Val Cost: 0.236
# Epoch 900, Train Cost: 0.000	Val Cost: 0.241
#
# Test Cost: 0.120
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.720	Val Cost: 0.571
# Epoch 100, Train Cost: 0.364	Val Cost: 0.373
# Epoch 200, Train Cost: 0.062	Val Cost: 0.324
# Epoch 300, Train Cost: 0.010	Val Cost: 0.170
# Epoch 400, Train Cost: 0.002	Val Cost: 0.195
# Epoch 500, Train Cost: 0.001	Val Cost: 0.209
# Epoch 600, Train Cost: 0.001	Val Cost: 0.219
# Epoch 700, Train Cost: 0.001	Val Cost: 0.226
# Epoch 800, Train Cost: 0.000	Val Cost: 0.232
# Epoch 900, Train Cost: 0.000	Val Cost: 0.237
#
# Test Cost: 0.141
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.998	Val Cost: 0.681
# Epoch 100, Train Cost: 0.553	Val Cost: 0.681
# Epoch 200, Train Cost: 0.247	Val Cost: 0.282
# Epoch 300, Train Cost: 0.069	Val Cost: 0.178
# Epoch 400, Train Cost: 0.009	Val Cost: 0.191
# Epoch 500, Train Cost: 0.003	Val Cost: 0.189
# Epoch 600, Train Cost: 0.001	Val Cost: 0.208
# Epoch 700, Train Cost: 0.001	Val Cost: 0.219
# Epoch 800, Train Cost: 0.001	Val Cost: 0.227
# Epoch 900, Train Cost: 0.000	Val Cost: 0.233
#
# Test Cost: 0.126
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.630	Val Cost: 0.523
# Epoch 100, Train Cost: 0.310	Val Cost: 0.309
# Epoch 200, Train Cost: 0.095	Val Cost: 0.164
# Epoch 300, Train Cost: 0.005	Val Cost: 0.180
# Epoch 400, Train Cost: 0.002	Val Cost: 0.204
# Epoch 500, Train Cost: 0.001	Val Cost: 0.217
# Epoch 600, Train Cost: 0.001	Val Cost: 0.226
# Epoch 700, Train Cost: 0.001	Val Cost: 0.233
# Epoch 800, Train Cost: 0.000	Val Cost: 0.238
# Epoch 900, Train Cost: 0.000	Val Cost: 0.243
#
# Test Cost: 0.140
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.583	Val Cost: 0.531
# Epoch 100, Train Cost: 0.306	Val Cost: 0.330
# Epoch 200, Train Cost: 0.191	Val Cost: 0.233
# Epoch 300, Train Cost: 0.156	Val Cost: 0.248
# Epoch 400, Train Cost: 0.134	Val Cost: 0.253
# Epoch 500, Train Cost: 0.121	Val Cost: 0.263
# Epoch 600, Train Cost: 0.111	Val Cost: 0.273
# Epoch 700, Train Cost: 0.104	Val Cost: 0.285
# Epoch 800, Train Cost: 0.098	Val Cost: 0.297
# Epoch 900, Train Cost: 0.094	Val Cost: 0.310
#
# Test Cost: 0.094
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.811	Val Cost: 0.639
# Epoch 100, Train Cost: 0.215	Val Cost: 0.222
# Epoch 200, Train Cost: 0.030	Val Cost: 0.156
# Epoch 300, Train Cost: 0.011	Val Cost: 0.167
# Epoch 400, Train Cost: 0.004	Val Cost: 0.176
# Epoch 500, Train Cost: 0.002	Val Cost: 0.188
# Epoch 600, Train Cost: 0.002	Val Cost: 0.197
# Epoch 700, Train Cost: 0.001	Val Cost: 0.205
# Epoch 800, Train Cost: 0.001	Val Cost: 0.210
# Epoch 900, Train Cost: 0.001	Val Cost: 0.215
#
# Test Cost: 0.090
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.709	Val Cost: 0.690
# Epoch 100, Train Cost: 0.338	Val Cost: 0.352
# Epoch 200, Train Cost: 0.314	Val Cost: 0.337
# Epoch 300, Train Cost: 0.307	Val Cost: 0.316
# Epoch 400, Train Cost: 0.264	Val Cost: 0.300
# Epoch 500, Train Cost: 0.259	Val Cost: 0.303
# Epoch 600, Train Cost: 0.258	Val Cost: 0.306
# Epoch 700, Train Cost: 0.257	Val Cost: 0.308
# Epoch 800, Train Cost: 0.255	Val Cost: 0.310
# Epoch 900, Train Cost: 0.245	Val Cost: 0.306
#
# Test Cost: 0.385
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.763	Val Cost: 0.668
# Epoch 100, Train Cost: 0.293	Val Cost: 0.320
# Epoch 200, Train Cost: 0.275	Val Cost: 0.309
# Epoch 300, Train Cost: 0.193	Val Cost: 0.265
# Epoch 400, Train Cost: 0.027	Val Cost: 0.178
# Epoch 500, Train Cost: 0.003	Val Cost: 0.193
# Epoch 600, Train Cost: 0.001	Val Cost: 0.211
# Epoch 700, Train Cost: 0.001	Val Cost: 0.221
# Epoch 800, Train Cost: 0.001	Val Cost: 0.229
# Epoch 900, Train Cost: 0.000	Val Cost: 0.235
#
# Test Cost: 0.138
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.706	Val Cost: 0.649
# Epoch 100, Train Cost: 0.224	Val Cost: 0.329
# Epoch 200, Train Cost: 0.017	Val Cost: 0.165
# Epoch 300, Train Cost: 0.003	Val Cost: 0.187
# Epoch 400, Train Cost: 0.001	Val Cost: 0.204
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.223
# Epoch 700, Train Cost: 0.000	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.235
# Epoch 900, Train Cost: 0.000	Val Cost: 0.239
#
# Test Cost: 0.142
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.671	Val Cost: 0.653
# Epoch 100, Train Cost: 0.383	Val Cost: 0.372
# Epoch 200, Train Cost: 0.366	Val Cost: 0.264
# Epoch 300, Train Cost: 0.005	Val Cost: 0.174
# Epoch 400, Train Cost: 0.001	Val Cost: 0.198
# Epoch 500, Train Cost: 0.001	Val Cost: 0.212
# Epoch 600, Train Cost: 0.001	Val Cost: 0.221
# Epoch 700, Train Cost: 0.001	Val Cost: 0.228
# Epoch 800, Train Cost: 0.000	Val Cost: 0.233
# Epoch 900, Train Cost: 0.000	Val Cost: 0.238
#
# Test Cost: 0.121
# hidden.W (2, 8)
# hidden.b (8,)
# hidden.W (8, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.754	Val Cost: 0.523
# Epoch 100, Train Cost: 0.507	Val Cost: 0.515
# Epoch 200, Train Cost: 0.254	Val Cost: 0.714
# Epoch 300, Train Cost: 0.198	Val Cost: 0.323
# Epoch 400, Train Cost: 0.003	Val Cost: 0.240
# Epoch 500, Train Cost: 0.001	Val Cost: 0.274
# Epoch 600, Train Cost: 0.001	Val Cost: 0.294
# Epoch 700, Train Cost: 0.001	Val Cost: 0.309
# Epoch 800, Train Cost: 0.000	Val Cost: 0.321
# Epoch 900, Train Cost: 0.000	Val Cost: 0.330
#
# Test Cost: 0.159
# hidden.W (2, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.546	Val Cost: 0.519
# Epoch 100, Train Cost: 0.310	Val Cost: 0.336
# Epoch 200, Train Cost: 0.308	Val Cost: 0.335
# Epoch 300, Train Cost: 0.306	Val Cost: 0.335
# Epoch 400, Train Cost: 0.302	Val Cost: 0.333
# Epoch 500, Train Cost: 0.294	Val Cost: 0.333
# Epoch 600, Train Cost: 0.286	Val Cost: 0.332
# Epoch 700, Train Cost: 0.279	Val Cost: 0.330
# Epoch 800, Train Cost: 0.274	Val Cost: 0.329
# Epoch 900, Train Cost: 0.270	Val Cost: 0.329
#
# Test Cost: 0.292
# hidden.W (2, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.750	Val Cost: 0.601
# Epoch 100, Train Cost: 0.138	Val Cost: 0.297
# Epoch 200, Train Cost: 0.018	Val Cost: 0.172
# Epoch 300, Train Cost: 0.011	Val Cost: 0.189
# Epoch 400, Train Cost: 0.003	Val Cost: 0.202
# Epoch 500, Train Cost: 0.002	Val Cost: 0.214
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.001	Val Cost: 0.231
# Epoch 800, Train Cost: 0.001	Val Cost: 0.237
# Epoch 900, Train Cost: 0.001	Val Cost: 0.243
#
# Test Cost: 0.069
# hidden.W (2, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.733	Val Cost: 0.688
# Epoch 100, Train Cost: 0.428	Val Cost: 0.546
# Epoch 200, Train Cost: 0.048	Val Cost: 0.157
# Epoch 300, Train Cost: 0.005	Val Cost: 0.175
# Epoch 400, Train Cost: 0.002	Val Cost: 0.204
# Epoch 500, Train Cost: 0.001	Val Cost: 0.215
# Epoch 600, Train Cost: 0.001	Val Cost: 0.223
# Epoch 700, Train Cost: 0.001	Val Cost: 0.229
# Epoch 800, Train Cost: 0.000	Val Cost: 0.233
# Epoch 900, Train Cost: 0.000	Val Cost: 0.237
#
# Test Cost: 0.137
# hidden.W (2, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.804	Val Cost: 0.683
# Epoch 100, Train Cost: 0.177	Val Cost: 0.272
# Epoch 200, Train Cost: 0.017	Val Cost: 0.155
# Epoch 300, Train Cost: 0.002	Val Cost: 0.187
# Epoch 400, Train Cost: 0.001	Val Cost: 0.205
# Epoch 500, Train Cost: 0.001	Val Cost: 0.216
# Epoch 600, Train Cost: 0.001	Val Cost: 0.224
# Epoch 700, Train Cost: 0.000	Val Cost: 0.230
# Epoch 800, Train Cost: 0.000	Val Cost: 0.235
# Epoch 900, Train Cost: 0.000	Val Cost: 0.240
#
# Test Cost: 0.144
# hidden.W (2, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)
# Epoch 0, Train Cost: 0.733	Val Cost: 0.568
# Epoch 100, Train Cost: 0.440	Val Cost: 0.834
# Epoch 200, Train Cost: 0.082	Val Cost: 0.151
# Epoch 300, Train Cost: 0.125	Val Cost: 0.182
# Epoch 400, Train Cost: 0.002	Val Cost: 0.190
# Epoch 500, Train Cost: 0.001	Val Cost: 0.206
# Epoch 600, Train Cost: 0.001	Val Cost: 0.217
# Epoch 700, Train Cost: 0.001	Val Cost: 0.225
# Epoch 800, Train Cost: 0.000	Val Cost: 0.231
# Epoch 900, Train Cost: 0.000	Val Cost: 0.236
#
# Test Cost: 0.151
# hidden.W (2, 7)
# hidden.b (7,)
# hidden.W (7, 6)
# hidden.b (6,)
# hidden.W (6, 5)
# hidden.b (5,)
# hidden.W (5, 4)
# hidden.b (4,)
# hidden.W (4, 3)
# hidden.b (3,)
# hidden.W (3, 2)
# hidden.b (2,)
# outputlayer.W (2, 2)
# outputlayer.b (2,)

# %%
test_errors = np.array(test_errors)

# %%
test_errors.shape
# Out:
# (10, 7, 3)

# %%
mean_test_error = test_errors.mean(axis=0)
std_test_error = test_errors.std(axis=0)
plt.plot(range(1,8), mean_test_error)
for error_type in range(test_errors.shape[-1]):
    plt.fill_between(range(1,8), mean_test_error[:,error_type]-std_test_error[:,error_type], mean_test_error[:,error_type]+std_test_error[:,error_type],color='k',alpha=0.1)
plt.xlabel('Number of hidden units in layer')
plt.ylabel('Mean test cost +- standard deviation across 10 initializations')

# %% [markdown]
#   3) Overfitting: When increasing the number of hidden layers / units the neural network will fit the training data better by creating a highly nonlinear decision boundary. If the model is too complex it will often generalize poorly to new data (validation and test set). Can you observe this from the training and validation errors?
#
#  3) We used the vanilla stocastic gradient descent algorithm for parameter updates. This is usually slow to converge and more sophisticated pseudo-second-order methods usually works better. Try changing the optimizer to [adam or adamax](http://lasagne.readthedocs.io/en/latest/modules/updates.html) (lasagne.updates.adam, lasagne.updates.adamax)

# %% [markdown]
# # MNIST Exercise
# MNIST is a dataset that is often used for benchmarking. The MNIST dataset consists of 70,000 images of handwritten digits from 0-9. The dataset is split into 50,000 images for training, 10,000 images for validation and 10,000 images for testing. The images are 28x28 pixels, where each pixel represents a normalised value between 0-255 (0=black and 255=white).
#
# ### Permutation invariance...
# We use a feed-forward neural network to classify the 28x28 MNIST images. ``num_features`` is therefore 28x28=784, hence we represent each image as a vector. The ordering of the pixels in the vector does not matter, so we could permutate all images using the same permuatation and still get the same performance. (You are of course encouraged to try this by ``numpy.random.permutation`` to get a random permutation :)). This task is therefore called the _permutation invariant_ MNIST. Obviously this throws away a lot of structure in the data. Next week we'll fix this with the convolutional neural network that encodes prior knowledge about data that has either spatial or temporal structure.
#
# ### Ballpark estimates of hyperparameters
# __Optimizers:__
#     1. SGD + Momentum: learning rate 1.0 - 0.1
#     2. ADAM: learning rate 3*1e-4 - 1e-5
#     3. RMSPROP: somewhere between SGD and ADAM
#
# __Regularization:__
#     1. Dropout. Dropout rate 0.1-0.5.
#     2. L2/L1 regularization.  http://lasagne.readthedocs.io/en/latest/modules/regularization.html . We don't use this that often but 1e-4  -  1e-8.
#
#     3. Batchnorm: Batchnorm also act as a regularizer
#
# __Parameter initialization__
#     Parameter initialization is extremely important. [Lasagne has a lot of different units](http://lasagne.readthedocs.io/en/latest/modules/init.html). Often used initializer use
#     1. He
#     2. Glorot
#     3. Uniform or Normal with small scale. (0.1 - 0.01)
#     4. Orthogonal (I find that this works very well for RNNs)
#
# Bias is nearly always initialized to zero.
#
# __Number of hidden units and network structure__
#    Probably as big network as possible and then apply regularization. You'll have to experiment :). One rarely goes below 512 units for feedforward networks unless you are training on CPU...
#    There is some research into stochastic depth networks: https://arxiv.org/pdf/1603.09382v2.pdf, but in general this is trial and error.
#
# __Nonlinearity__: [The most commonly used nonliearities are](http://lasagne.readthedocs.io/en/latest/modules/nonlinearities.html)
#
#     1. ReLU
#     2. Leaky ReLU.
#     3. Elu
#     3. Sigmoids are used if your output is binary. It is not used in the hidden layers (anymore). Limits the output between 0 and 1.
#     4. Softmax is used as output if you have a classification problem. Normalizes the output to 1.
#
#
# See the plot below.
#
# __mini-batch size__
#    Usually people use 16-256. Bigger is not always better. With smaller mini-batch sizes you get more updates and your model might converge faster. Also small batchsizes use less memory  -> you can use a bigger model.
#
# Hyperparameters can be found by experience (guessing) or some search procedure. Random search is easy to implement and performs decent: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf .
# More advanced search procedures include [SPEARMINT](https://github.com/JasperSnoek/spearmint) and many others.

# %%
# PLOT OF DIFFERENT OUTPUT USNITS
x = np.linspace(-6, 6, 100)
relu = lambda x: np.maximum(0, x)
leaky_relu = lambda x: np.maximum(0, x) + 0.1*np.minimum(0, x) # probably a slow implementation....
elu = lambda x: (x > 0)*x + (1 - (x > 0))*(np.exp(x) - 1) 
sigmoid = lambda x: (1+np.exp(-x))**(-1)

plt.figure(figsize=(6,6))
plt.plot(x, relu(x), label='ReLU', lw=2)
plt.plot(x, leaky_relu(x), label='Leaky ReLU',lw=2)
plt.plot(x, elu(x), label='Elu', lw=2)
plt.plot(x, sigmoid(x), label='Sigmoid',lw=2)
plt.legend(loc=2, fontsize=16)
plt.title('Non-linearities', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])
# Out:
# (-6, 6)

# %% [markdown]
# ## MNIST
# First let's load the MNIST dataset and plot a few examples:

# %%
#To speed up training we'll only work on a subset of the data
data = np.load('mnist.npz')
num_classes = 10
x_train = data['X_train'][:1000].astype('float32')
targets_train = data['y_train'][:1000].astype('int32')

x_valid = data['X_valid'][:500].astype('float32')
targets_valid = data['y_valid'][:500].astype('int32')

x_test = data['X_test'][:500].astype('float32')
targets_test = data['y_test'][:500].astype('int32')

# %%
#plot a few MNIST examples
idx = 0
canvas = np.zeros((28*10, 10*28))
for i in range(10):
    for j in range(10):
        canvas[i*28:(i+1)*28, j*28:(j+1)*28] = x_train[idx].reshape((28, 28))
        idx += 1
plt.figure(figsize=(7, 7))
plt.axis('off')
plt.imshow(canvas, cmap='gray')
plt.title('MNIST handwritten digits')
plt.show()

# %%
#define the model
num_class = 10
num_features = x_train.shape[1]

l_in = InputLayer(shape=(None,num_features))
l_hid = DenseLayer(incoming=l_in, num_units=500, nonlinearity=elu)
l_out = DenseLayer(incoming=l_hid, num_units=num_class, nonlinearity=softmax)

# %%
sym_x = T.matrix('sym_x') # a symbolic variable taking on the value of a input batch.
sym_t = T.ivector('sym_t') # a symbolic variable taking on the value of the target batch.

# Get network output
train_out = lasagne.layers.get_output(l_out, sym_x, deterministic=False)
eval_out = lasagne.layers.get_output(l_out, sym_x, deterministic=True)


# Get list of all trainable parameters in the network.
all_params = lasagne.layers.get_all_params(l_out, trainable=True)

cost = T.nnet.categorical_crossentropy(train_out+1e-8, sym_t).mean()
# Let Theano do its magic and get all the gradients we need for training
all_grads = T.grad(cost, all_params)


# Set the update function for parameters 
# you might wan't to experiment with more advanded update schemes like rmsprob, adadelta etc.
updates = lasagne.updates.sgd(all_grads, all_params, learning_rate=0.1)


f_eval = theano.function([sym_x],
                     eval_out, on_unused_input='warn')

f_train = theano.function([sym_x, sym_t],
                          [cost],
                          updates=updates, on_unused_input='warn')

# %%
#Test the forward pass
x = np.random.normal(0,1, (45, 28*28)).astype('float32') #dummy data

model = lasagne.layers.get_output(l_out, sym_x)
out = model.eval({sym_x:x}) #this could also include mask etc if used
print("l_out dim(%i, %i)." % out.shape)

# %% [markdown]
# # Build the training loop.
# We train the network by calculating the gradient w.r.t the cost function and update the parameters in direction of the negative gradient.
#
#
# When training neural networks you always use mini batches. Instead of calculating the average gradient using the entire dataset you approximate the gradient using a mini-batch of typically 16 to 256 samples. The parameters are updated after each mini batch.
#
# We build a loop that iterates over the training data. Remember that the parameters are updated each time ``f_train`` is called.

# %%
from confusionmatrix import ConfusionMatrix
batch_size = 100
num_epochs = 100
learning_rate = 0.1
num_samples_train = x_train.shape[0]
num_batches_train = num_samples_train // batch_size
num_samples_valid = x_valid.shape[0]
num_batches_valid = num_samples_valid // batch_size

train_acc, train_loss = [], []
valid_acc, valid_loss = [], []
test_acc, test_loss = [], []
cur_loss = 0
loss = []
for epoch in range(num_epochs):
    #Forward->Backprob->Update params
    cur_loss = 0
    for i in range(num_batches_train):
        idx = range(i*batch_size, (i+1)*batch_size)
        x_batch = x_train[idx]
        target_batch = targets_train[idx]    
        batch_loss = f_train(x_batch,target_batch) #this will do the complete backprob pass
        cur_loss += batch_loss[0]
    loss += [cur_loss/batch_size]
    
    confusion_valid = ConfusionMatrix(num_classes)
    confusion_train = ConfusionMatrix(num_classes)

    for i in range(num_batches_train):
        idx = range(i*batch_size, (i+1)*batch_size)
        x_batch = x_train[idx]
        targets_batch = targets_train[idx]
        net_out = f_eval(x_batch)   
        preds = np.argmax(net_out, axis=-1) 
        confusion_train.batch_add(targets_batch, preds)

    confusion_valid = ConfusionMatrix(num_classes)
    for i in range(num_batches_valid):
        idx = range(i*batch_size, (i+1)*batch_size)
        x_batch = x_valid[idx]
        targets_batch = targets_valid[idx]
        net_out = f_eval(x_batch)   
        preds = np.argmax(net_out, axis=-1) 
        
        confusion_valid.batch_add(targets_batch, preds)
    
    train_acc_cur = confusion_train.accuracy()
    valid_acc_cur = confusion_valid.accuracy()

    train_acc += [train_acc_cur]
    valid_acc += [valid_acc_cur]
    print("Epoch %i : Train Loss %e , Train acc %f,  Valid acc %f " \
    % (epoch+1, loss[-1], train_acc_cur, valid_acc_cur))

# %%
epoch = np.arange(len(train_acc))
plt.figure(figsize=(12,6))
plt.plot(epoch,train_acc,'r',epoch,valid_acc,'b')
plt.legend(['Train Acc','Val Acc'])
plt.xlabel('Updates'), plt.ylabel('Acc')

# %% [markdown]
# # More questions (NOTE that before retraining, the network must be reinitialized.)

# %% [markdown]
# 1. Do you see overfitting? Google overfitting if you don't know how to spot it.
# 2. Regularization is a method to reduce overfitting. Adding noise to your network is a popular method to fight overfitting. Try using Dropout in your network. [Lasagne DropoutLayer](http://lasagne.readthedocs.io/en/latest/modules/layers/noise.html#lasagne.layers.DropoutLayer).
# 3. Alternatively you can regularize your network by penalizing the L2 or L1 norm of the network parameters. [Read the docs for more info](http://lasagne.readthedocs.io/en/latest/modules/regularization.html).
